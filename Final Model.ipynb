# %%
import pandas as pd
import numpy as np
import copy
import datetime               
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_columns',None)
pd.options.mode.chained_assignment = None

import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn import svm
from sklearn.model_selection import KFold 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, LinearRegression, Lasso
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_curve, auc, roc_auc_score, precision_recall_curve
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import GridSearchCV, cross_val_score, TimeSeriesSplit
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.linear_model import Lasso, LassoCV
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier

# %%
seed = 42
np.random.seed(seed)

# %% [markdown]
# # Import Merged Data

# %%
cm = pd.read_csv('cleaned_and_merged_data.csv')

# %%
cm.head()
# Out:
#     LPERMNO              sic   fyear  oancf/sale  ebitda/sale   gp/sale  \
# 3     10031     Retail Trade  1987.0   -0.026421     0.002971  0.363770
# 4     10031     Retail Trade  1988.0   -0.064009    -0.112168  0.337966
# 9     54594  Wholesale Trade  1988.0    0.000231     0.125630  0.254218
# 10    54594  Wholesale Trade  1989.0    0.043543     0.121454  0.242639
# 11    54594  Wholesale Trade  1990.0    0.079073     0.089932  0.215419
#
#          ros  gross_margin  oancf/seq  oancf/at   ebit/seq   ebit/at  \
# 3   0.004979      0.363770  -0.129138 -0.061526  -0.052990 -0.025246
# 4  -0.238905      0.337966  10.824742 -0.128993  22.536082 -0.268550
# 9   0.061064      0.254218   0.000548  0.000264   0.260024  0.125186
# 10  0.057668      0.242639   0.102196  0.049858   0.247172  0.120588
# 11  0.031725      0.215419   0.190378  0.097092   0.173916  0.088697
#
#     ebitda/at        roe       roa  xint/sale  effective_tax_rate    fin_lev  \
# 3    0.006919   0.024336  0.011595   0.013438            0.421169   2.098914
# 4   -0.226044  40.402062 -0.481450   0.022159            0.088499 -83.917526
# 9    0.143244   0.144621  0.069626   0.019217            0.329605   2.077113
# 10   0.139071   0.135348  0.066032   0.022453            0.327611   2.049724
# 11   0.110425   0.076381  0.038954   0.021591            0.306777   1.960790
#
#     dltt/seq   dltt/at   wcap/at     ch/at     at/lt     lt/at   invt/at  \
# 3   0.716734  0.341479  0.301906  0.029610  1.909989  0.523563  0.743174
# 4  -0.536082  0.006388 -0.052243  0.018550  0.988224  1.011916  0.717445
# 9   0.149825  0.072131  0.317315  0.012809  1.928408  0.518562  0.393705
# 10  0.381587  0.186165  0.415694  0.010409  1.952632  0.512129  0.417349
# 11  0.355835  0.181475  0.405477  0.004087  2.040810  0.490002  0.410922
#
#     asset_turnover  invt_turnover  invt/sale  receivable_turnover  \
# 3         2.328637       1.993541   0.319146            29.507109
# 4         2.015233       1.859589   0.356011            15.273743
# 9         1.140208       2.159857   0.345292             4.267680
# 10        1.145048       2.077910   0.364482             4.753903
# 11        1.227878       2.344411   0.334660             5.113461
#
#     payable_turnover  bankrupt  bankrupt_year    CPI     GDP  inflation  \
# 3          52.392707       0.0         1989.0  113.6  4855.2     0.0365
# 4          10.896048       0.0         1989.0  118.3  5236.4     0.0414
# 9          11.271809       0.0         2019.0  118.3  5236.4     0.0414
# 10         12.405538       0.0         2019.0  124.0  5641.6     0.0482
# 11         13.284604       0.0         2019.0  130.7  5963.1     0.0540
#
#     unemployment   spread
# 3          0.062  0.97704
# 4          0.055  0.74760
# 9          0.055  0.74760
# 10         0.053 -0.07868
# 11         0.056  0.39088

# %% [markdown]
# ### Clean data a bit

# %%
cm['CPI'] = np.log10(cm['CPI'])
cm['GDP'] = np.log10(cm['GDP'])

# %% [markdown]
# # Lag one year ahead #

# %%
# year_lag = lag for x years 
# e.g. a row with 2018 data -- year_lag = 2 -- (2018) 2017 2016

def lag(data, year_lag = 2):

    # change the fyear to ascend within every LPERMNO
    data.sort_values(['LPERMNO', 'fyear'], ascending = [True, True], inplace = True)

    # remove irrelevant columns first
    df = data.drop(columns = ['bankrupt','bankrupt_year'])
    
    # get the columns
    columns = df.columns
    col_to_lag = columns[2:]

    # run the loops to create lag columns to the number of lagged year
    for lag in range(1, year_lag+1):
        for colname in col_to_lag:
            df[f'{colname}'+ '_lag' + f'{lag}'] = df[f'{colname}'].shift((lag-1))

    # # calcualte delta change 
    # for lag in range(1, year_lag):
    #     for colname in col_to_lag:
    #         if (f'{colname}'+ '_lag' + f'{lag+1}' in df.columns) and colname != 'fyear':
    #             df[f'{colname}' + '_change_lagyear' +f'{lag+1}'] = (df[f'{colname}'+ '_lag' + f'{lag}'] - df[f'{colname}'+ '_lag' + f'{lag+1}'])/df[f'{colname}'+ '_lag' + f'{lag+1}']

    # add back the bankrupt info
    df['bankrupt'] = data['bankrupt']
    df['bankrupt_year'] = data['bankrupt_year']

    # keep the new lagged columns and remove the original one
    df.drop(col_to_lag, axis=1, inplace = True)

    # drop the first row of each LPERMNO after lagging one year
    # will drop companies with only one year of data (49 companies)
    df = df.groupby(['LPERMNO']).apply(lambda x: x.iloc[1:])
    df = df.set_index('LPERMNO').reset_index()    
    
    # identify the real bankrupt row
    # will drop companies goes bankrupt after >1 year after the last fiscal year of recording (96 companies)
    for i in range(len(df)):
        if (df['bankrupt'][i] == 1) & (df['bankrupt_year'][i] == df['fyear_lag1'][i]):
            df.drop(i,inplace=True)
        elif (df['bankrupt'][i] == 1) & (df['bankrupt_year'][i] - df['fyear_lag1'][i] == 1):
            df['bankrupt'][i] = 1
        else:
            df['bankrupt'][i] = 0

    df['predict_year'] = df['fyear_lag1']+1

    return df

# cmcm = lag(cm[cm['tic'] == 'TSLA'],2)
cmcm = lag(cm ,2)
cmcm.head()
# Out:
#    LPERMNO                                                sic  fyear_lag1  \
# 0    10001  Transportation, Communications, Electric, Gas ...      1990.0
# 1    10001  Transportation, Communications, Electric, Gas ...      1991.0
# 2    10001  Transportation, Communications, Electric, Gas ...      1992.0
# 3    10001  Transportation, Communications, Electric, Gas ...      1993.0
# 4    10001  Transportation, Communications, Electric, Gas ...      1994.0
#
#    oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  ros_lag1  \
# 0         0.081543          0.142937      0.142937  0.048693
# 1         0.081929          0.132830      0.132830  0.044990
# 2         0.103007          0.126667      0.126667  0.036340
# 3         0.052988          0.145753      0.145753  0.046473
# 4         0.102999          0.148121      0.148121  0.048808
#
#    gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  ebit/seq_lag1  \
# 0           0.142937        0.263825       0.100312       0.342527
# 1           0.132830        0.244801       0.099699       0.302430
# 2           0.126667        0.289316       0.106076       0.235222
# 3           0.145753        0.167640       0.053364       0.313867
# 4           0.148121        0.303524       0.101477       0.280635
#
#    ebit/at_lag1  ebitda/at_lag1  roe_lag1  roa_lag1  xint/sale_lag1  \
# 0      0.130237        0.175838  0.157543  0.059901        0.035950
# 1      0.123170        0.161641  0.134427  0.054748        0.032495
# 2      0.086242        0.130441  0.102068  0.037423        0.035512
# 3      0.099913        0.146789  0.147029  0.046803        0.034674
# 4      0.093825        0.145933  0.143831  0.048087        0.034754
#
#    effective_tax_rate_lag1  fin_lev_lag1  dltt/seq_lag1  dltt/at_lag1  \
# 0                 0.361738      2.630032       0.999443      0.380012
# 1                 0.388952      2.455400       0.872588      0.355375
# 2                 0.345882      2.727451       0.824257      0.302208
# 3                 0.348884      3.141418       1.265315      0.402785
# 4                 0.341871      2.991057       1.141062      0.381491
#
#    wcap/at_lag1  ch/at_lag1  at/lt_lag1  lt/at_lag1  invt/at_lag1  \
# 0      0.055668    0.071818    1.613485    0.619776      0.011652
# 1      0.069350    0.081382    1.687096    0.592734      0.012654
# 2     -0.025011    0.049358    1.578888    0.633357      0.055326
# 3      0.068044    0.024969    1.466980    0.681672      0.058905
# 4      0.038945    0.018224    1.502246    0.665670      0.038726
#
#    asset_turnover_lag1  invt_turnover_lag1  invt/sale_lag1  \
# 0             1.230178           90.486364        0.009472
# 1             1.216899           83.395161        0.010398
# 2             1.029794           16.255474        0.053725
# 3             1.007108           14.605198        0.058489
# 4             0.985229           21.672794        0.039306
#
#    receivable_turnover_lag1  payable_turnover_lag1  CPI_lag1  GDP_lag1  \
# 0                 14.453640              20.356705  2.116276  3.775472
# 1                 12.672689              24.613003  2.134177  3.789447
# 2                 14.543726              19.565217  2.147058  3.814268
# 3                 10.157721              17.442551  2.159868  3.836235
# 4                 10.532725              21.898734  2.170848  3.862561
#
#    inflation_lag1  unemployment_lag1  spread_lag1  fyear_lag2  \
# 0           0.054              0.056     0.390880      1989.0
# 1           0.042              0.068     1.374600      1990.0
# 2           0.030              0.075     2.238964      1991.0
# 3           0.030              0.069     1.820480      1992.0
# 4           0.026              0.061     1.142209      1993.0
#
#    oancf/sale_lag2  ebitda/sale_lag2  gp/sale_lag2  ros_lag2  \
# 0         0.077346          0.133304      0.133304  0.052728
# 1         0.081543          0.142937      0.142937  0.048693
# 2         0.081929          0.132830      0.132830  0.044990
# 3         0.103007          0.126667      0.126667  0.036340
# 4         0.052988          0.145753      0.145753  0.046473
#
#    gross_margin_lag2  oancf/seq_lag2  oancf/at_lag2  ebit/seq_lag2  \
# 0           0.133304        0.280335       0.095448       0.379845
# 1           0.142937        0.263825       0.100312       0.342527
# 2           0.132830        0.244801       0.099699       0.302430
# 3           0.126667        0.289316       0.106076       0.235222
# 4           0.145753        0.167640       0.053364       0.313867
#
#    ebit/at_lag2  ebitda/at_lag2  roe_lag2  roa_lag2  xint/sale_lag2  \
# 0      0.129329        0.164503  0.191109  0.065069        0.028416
# 1      0.130237        0.175838  0.157543  0.059901        0.035950
# 2      0.123170        0.161641  0.134427  0.054748        0.032495
# 3      0.086242        0.130441  0.102068  0.037423        0.035512
# 4      0.099913        0.146789  0.147029  0.046803        0.034674
#
#    effective_tax_rate_lag2  fin_lev_lag2  dltt/seq_lag2  dltt/at_lag2  \
# 0                 0.368201      2.937035       1.165955      0.396984
# 1                 0.361738      2.630032       0.999443      0.380012
# 2                 0.388952      2.455400       0.872588      0.355375
# 3                 0.345882      2.727451       0.824257      0.302208
# 4                 0.348884      3.141418       1.265315      0.402785
#
#    wcap/at_lag2  ch/at_lag2  at/lt_lag2  lt/at_lag2  invt/at_lag2  \
# 0      0.037189    0.063399    1.516253    0.659521      0.012335
# 1      0.055668    0.071818    1.613485    0.619776      0.011652
# 2      0.069350    0.081382    1.687096    0.592734      0.012654
# 3     -0.025011    0.049358    1.578888    0.633357      0.055326
# 4      0.068044    0.024969    1.466980    0.681672      0.058905
#
#    asset_turnover_lag2  invt_turnover_lag2  invt/sale_lag2  \
# 0             1.234043           86.707424        0.009996
# 1             1.230178           90.486364        0.009472
# 2             1.216899           83.395161        0.010398
# 3             1.029794           16.255474        0.053725
# 4             1.007108           14.605198        0.058489
#
#    receivable_turnover_lag2  payable_turnover_lag2  CPI_lag2  GDP_lag2  \
# 0                 10.998560              20.185022  2.093422  3.751402
# 1                 14.453640              20.356705  2.116276  3.775472
# 2                 12.672689              24.613003  2.134177  3.789447
# 3                 14.543726              19.565217  2.147058  3.814268
# 4                 10.157721              17.442551  2.159868  3.836235
#
#    inflation_lag2  unemployment_lag2  spread_lag2  bankrupt  bankrupt_year  \
# 0          0.0482              0.053    -0.078680       0.0         2017.0
# 1          0.0540              0.056     0.390880       0.0         2017.0
# 2          0.0420              0.068     1.374600       0.0         2017.0
# 3          0.0300              0.075     2.238964       0.0         2017.0
# 4          0.0300              0.069     1.820480       0.0         2017.0
#
#    predict_year
# 0        1991.0
# 1        1992.0
# 2        1993.0
# 3        1994.0
# 4        1995.0

# %%
cmcm['bankrupt'].value_counts()
# Out:
# 0.0    94069
# 1.0      272
# Name: bankrupt, dtype: int64

# %%
cmcm[cmcm['predict_year'] != 2020]['bankrupt'].value_counts()
# Out:
# 0.0    93397
# 1.0      272
# Name: bankrupt, dtype: int64

# %% [markdown]
# ## Remove predict year = 2020

# %%
cmcm2020 = cmcm[cmcm['predict_year'] == 2020]

# %%
cmcm = cmcm[cmcm['predict_year'] != 2020]

# %%
cmcm
# Out:
#        LPERMNO                                                sic  fyear_lag1  \
# 0        10001  Transportation, Communications, Electric, Gas ...      1990.0
# 1        10001  Transportation, Communications, Electric, Gas ...      1991.0
# 2        10001  Transportation, Communications, Electric, Gas ...      1992.0
# 3        10001  Transportation, Communications, Electric, Gas ...      1993.0
# 4        10001  Transportation, Communications, Electric, Gas ...      1994.0
# ...        ...                                                ...         ...
# 94348    93436                                      Manufacturing      2014.0
# 94349    93436                                      Manufacturing      2015.0
# 94350    93436                                      Manufacturing      2016.0
# 94351    93436                                      Manufacturing      2017.0
# 94352    93436                                      Manufacturing      2018.0
#
#        oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  ros_lag1  \
# 0             0.081543          0.142937      0.142937  0.048693
# 1             0.081929          0.132830      0.132830  0.044990
# 2             0.103007          0.126667      0.126667  0.036340
# 3             0.052988          0.145753      0.145753  0.046473
# 4             0.102999          0.148121      0.148121  0.048808
# ...                ...               ...           ...       ...
# 94348        -0.017927          0.014145      0.348180 -0.091935
# 94349        -0.129633         -0.072674      0.332695 -0.219639
# 94350        -0.017690          0.043065      0.363758 -0.096414
# 94351        -0.005158          0.006031      0.328138 -0.166803
# 94352         0.097748          0.076181      0.276303 -0.045482
#
#        gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  ebit/seq_lag1  \
# 0               0.142937        0.263825       0.100312       0.342527
# 1               0.132830        0.244801       0.099699       0.302430
# 2               0.126667        0.289316       0.106076       0.235222
# 3               0.145753        0.167640       0.053364       0.313867
# 4               0.148121        0.303524       0.101477       0.280635
# ...                  ...             ...            ...            ...
# 94348           0.348180       -0.059116      -0.009802      -0.192482
# 94349           0.332695       -0.463753      -0.064813      -0.633630
# 94350           0.363758       -0.026005      -0.005464      -0.135590
# 94351           0.328138       -0.014314      -0.002117      -0.369358
# 94352           0.276303        0.426102       0.070539      -0.051356
#
#        ebit/at_lag1  ebitda/at_lag1  roe_lag1  roa_lag1  xint/sale_lag1  \
# 0          0.130237        0.175838  0.157543  0.059901        0.035950
# 1          0.123170        0.161641  0.134427  0.054748        0.032495
# 2          0.086242        0.130441  0.102068  0.037423        0.035512
# 3          0.099913        0.146789  0.147029  0.046803        0.034674
# 4          0.093825        0.145933  0.143831  0.048087        0.034754
# ...             ...             ...       ...       ...             ...
# 94348     -0.031917        0.007735 -0.303163 -0.050270        0.035533
# 94349     -0.088555       -0.036335 -0.785740 -0.109814        0.039626
# 94350     -0.028487        0.013301 -0.141738 -0.029779        0.035071
# 94351     -0.054618        0.002475 -0.462888 -0.068448        0.050700
# 94352     -0.008502        0.054975 -0.198262 -0.032821        0.033454
#
#        effective_tax_rate_lag1  fin_lev_lag1  dltt/seq_lag1  dltt/at_lag1  \
# 0                     0.361738      2.630032       0.999443      0.380012
# 1                     0.388952      2.455400       0.872588      0.355375
# 2                     0.345882      2.727451       0.824257      0.302208
# 3                     0.348884      3.141418       1.265315      0.402785
# 4                     0.341871      2.991057       1.141062      0.381491
# ...                        ...           ...            ...           ...
# 94348                -0.033039      6.030740       1.875218      0.310943
# 94349                -0.014891      7.155207       1.804063      0.252133
# 94350                -0.035772      4.759666       1.271367      0.267113
# 94351                -0.014280      6.762630       2.238742      0.331046
# 94352                -0.057564      6.040655       1.920290      0.317894
#
#        wcap/at_lag1  ch/at_lag1  at/lt_lag1  lt/at_lag1  invt/at_lag1  \
# 0          0.055668    0.071818    1.613485    0.619776      0.011652
# 1          0.069350    0.081382    1.687096    0.592734      0.012654
# 2         -0.025011    0.049358    1.578888    0.633357      0.055326
# 3          0.068044    0.024969    1.466980    0.681672      0.058905
# 4          0.038945    0.018224    1.502246    0.665670      0.038726
# ...             ...         ...         ...         ...           ...
# 94348      0.341266    0.325805    1.198778    0.834183      0.163042
# 94349     -0.006106    0.147904    1.162464    0.860242      0.157905
# 94350      0.061826    0.149718    1.353066    0.739062      0.091222
# 94351     -0.093900    0.117532    1.244642    0.803444      0.078992
# 94352     -0.078552    0.123930    1.269513    0.787704      0.104690
#
#        asset_turnover_lag1  invt_turnover_lag1  invt/sale_lag1  \
# 0                 1.230178           90.486364        0.009472
# 1                 1.216899           83.395161        0.010398
# 2                 1.029794           16.255474        0.053725
# 3                 1.007108           14.605198        0.058489
# 4                 0.985229           21.672794        0.039306
# ...                    ...                 ...             ...
# 94348             0.546798            2.186021        0.298177
# 94349             0.499975            2.112891        0.315826
# 94350             0.308865            2.154232        0.295345
# 94351             0.410351            3.490228        0.192498
# 94352             0.721639            4.988511        0.145073
#
#        receivable_turnover_lag1  payable_turnover_lag1  CPI_lag1  GDP_lag1  \
# 0                     14.453640              20.356705  2.116276  3.775472
# 1                     12.672689              24.613003  2.134177  3.789447
# 2                     14.543726              19.565217  2.147058  3.814268
# 3                     10.157721              17.442551  2.159868  3.836235
# 4                     10.532725              21.898734  2.170848  3.862561
# ...                         ...                    ...       ...       ...
# 94348                 14.114296               4.111283  2.374272  4.243715
# 94349                 23.945936               4.416344  2.374785  4.260663
# 94350                 14.024330               3.762822  2.380229  4.272190
# 94351                 22.815647               4.919465  2.389379  4.290466
# 94352                 22.614089               6.303885  2.399864  4.313450
#
#        inflation_lag1  unemployment_lag1  spread_lag1  fyear_lag2  \
# 0               0.054              0.056     0.390880      1989.0
# 1               0.042              0.068     1.374600      1990.0
# 2               0.030              0.075     2.238964      1991.0
# 3               0.030              0.069     1.820480      1992.0
# 4               0.026              0.061     1.142209      1993.0
# ...               ...                ...          ...         ...
# 94348           0.016              0.062     2.077480      2013.0
# 94349           0.001              0.053     1.451514      2014.0
# 94350           0.013              0.049     1.003240      2015.0
# 94351           0.021              0.044     0.930280      2016.0
# 94352           0.024              0.039     0.384177      2017.0
#
#        oancf/sale_lag2  ebitda/sale_lag2  gp/sale_lag2  ros_lag2  \
# 0             0.077346          0.133304      0.133304  0.052728
# 1             0.081543          0.142937      0.142937  0.048693
# 2             0.081929          0.132830      0.132830  0.044990
# 3             0.103007          0.126667      0.126667  0.036340
# 4             0.052988          0.145753      0.145753  0.046473
# ...                ...               ...           ...       ...
# 94348         0.128132          0.022250      0.279288 -0.036759
# 94349        -0.017927          0.014145      0.348180 -0.091935
# 94350        -0.129633         -0.072674      0.332695 -0.219639
# 94351        -0.017690          0.043065      0.363758 -0.096414
# 94352        -0.005158          0.006031      0.328138 -0.166803
#
#        gross_margin_lag2  oancf/seq_lag2  oancf/at_lag2  ebit/seq_lag2  \
# 0               0.133304        0.280335       0.095448       0.379845
# 1               0.142937        0.263825       0.100312       0.342527
# 2               0.132830        0.244801       0.099699       0.302430
# 3               0.126667        0.289316       0.106076       0.235222
# 4               0.145753        0.167640       0.053364       0.313867
# ...                  ...             ...            ...            ...
# 94348           0.279288        0.386728       0.106745      -0.091862
# 94349           0.348180       -0.059116      -0.009802      -0.192482
# 94350           0.332695       -0.463753      -0.064813      -0.633630
# 94351           0.363758       -0.026005      -0.005464      -0.135590
# 94352           0.328138       -0.014314      -0.002117      -0.369358
#
#        ebit/at_lag2  ebitda/at_lag2  roe_lag2  roa_lag2  xint/sale_lag2  \
# 0          0.129329        0.164503  0.191109  0.065069        0.028416
# 1          0.130237        0.175838  0.157543  0.059901        0.035950
# 2          0.123170        0.161641  0.134427  0.054748        0.032495
# 3          0.086242        0.130441  0.102068  0.037423        0.035512
# 4          0.099913        0.146789  0.147029  0.046803        0.034674
# ...             ...             ...       ...       ...             ...
# 94348     -0.025356        0.018536 -0.110946 -0.030623        0.009957
# 94349     -0.031917        0.007735 -0.303163 -0.050270        0.035533
# 94350     -0.088555       -0.036335 -0.785740 -0.109814        0.039626
# 94351     -0.028487        0.013301 -0.141738 -0.029779        0.035071
# 94352     -0.054618        0.002475 -0.462888 -0.068448        0.050700
#
#        effective_tax_rate_lag2  fin_lev_lag2  dltt/seq_lag2  dltt/at_lag2  \
# 0                     0.368201      2.937035       1.165955      0.396984
# 1                     0.361738      2.630032       0.999443      0.380012
# 2                     0.388952      2.455400       0.872588      0.355375
# 3                     0.345882      2.727451       0.824257      0.302208
# 4                     0.348884      3.141418       1.265315      0.402785
# ...                        ...           ...            ...           ...
# 94348                -0.036233      3.622931       0.897850      0.247824
# 94349                -0.033039      6.030740       1.875218      0.310943
# 94350                -0.014891      7.155207       1.804063      0.252133
# 94351                -0.035772      4.759666       1.271367      0.267113
# 94352                -0.014280      6.762630       2.238742      0.331046
#
#        wcap/at_lag2  ch/at_lag2  at/lt_lag2  lt/at_lag2  invt/at_lag2  \
# 0          0.037189    0.063399    1.516253    0.659521      0.012335
# 1          0.055668    0.071818    1.613485    0.619776      0.011652
# 2          0.069350    0.081382    1.687096    0.592734      0.012654
# 3         -0.025011    0.049358    1.578888    0.633357      0.055326
# 4          0.068044    0.024969    1.466980    0.681672      0.058905
# ...             ...         ...         ...         ...           ...
# 94348      0.293410    0.349985    1.381253    0.723980      0.140821
# 94349      0.341266    0.325805    1.198778    0.834183      0.163042
# 94350     -0.006106    0.147904    1.162464    0.860242      0.157905
# 94351      0.061826    0.149718    1.353066    0.739062      0.091222
# 94352     -0.093900    0.117532    1.244642    0.803444      0.078992
#
#        asset_turnover_lag2  invt_turnover_lag2  invt/sale_lag2  \
# 0                 1.234043           86.707424        0.009996
# 1                 1.230178           90.486364        0.009472
# 2                 1.216899           83.395161        0.010398
# 3                 1.029794           16.255474        0.053725
# 4                 1.007108           14.605198        0.058489
# ...                    ...                 ...             ...
# 94348             0.833080            4.263639        0.169037
# 94349             0.546798            2.186021        0.298177
# 94350             0.499975            2.112891        0.315826
# 94351             0.308865            2.154232        0.295345
# 94352             0.410351            3.490228        0.192498
#
#        receivable_turnover_lag2  payable_turnover_lag2  CPI_lag2  GDP_lag2  \
# 0                     10.998560              20.185022  2.093422  3.751402
# 1                     14.453640              20.356705  2.116276  3.775472
# 2                     12.672689              24.613003  2.134177  3.789447
# 3                     14.543726              19.565217  2.147058  3.814268
# 4                     10.157721              17.442551  2.159868  3.836235
# ...                         ...                    ...       ...       ...
# 94348                 41.000550               6.624018  2.367281  4.224919
# 94349                 14.114296               4.111283  2.374272  4.243715
# 94350                 23.945936               4.416344  2.374785  4.260663
# 94351                 14.024330               3.762822  2.380229  4.272190
# 94352                 22.815647               4.919465  2.389379  4.290466
#
#        inflation_lag2  unemployment_lag2  spread_lag2  bankrupt  \
# 0              0.0482              0.053    -0.078680       0.0
# 1              0.0540              0.056     0.390880       0.0
# 2              0.0420              0.068     1.374600       0.0
# 3              0.0300              0.075     2.238964       0.0
# 4              0.0300              0.069     1.820480       0.0
# ...               ...                ...          ...       ...
# 94348          0.0150              0.074     2.043080       0.0
# 94349          0.0160              0.062     2.077480       0.0
# 94350          0.0010              0.053     1.451514       0.0
# 94351          0.0130              0.049     1.003240       0.0
# 94352          0.0210              0.044     0.930280       0.0
#
#        bankrupt_year  predict_year
# 0             2017.0        1991.0
# 1             2017.0        1992.0
# 2             2017.0        1993.0
# 3             2017.0        1994.0
# 4             2017.0        1995.0
# ...              ...           ...
# 94348         2019.0        2015.0
# 94349         2019.0        2016.0
# 94350         2019.0        2017.0
# 94351         2019.0        2018.0
# 94352         2019.0        2019.0
#
# [93669 rows x 71 columns]

# %% [markdown]
# # Split Data set

# %%
# Split data: year 1985-2005 as training set(35%) and year 2006-2019 as test set(65%)
# Reasoning: two economic cycle, also two crisis in the training set, one in the test set 

train = cmcm[cmcm['predict_year']<=2006]
test = cmcm[cmcm['predict_year']>2006]

len(train)/len(cmcm)
# Out:
# 0.6509517556502151

# %%
train.head(3)
# Out:
#    LPERMNO                                                sic  fyear_lag1  \
# 0    10001  Transportation, Communications, Electric, Gas ...      1990.0
# 1    10001  Transportation, Communications, Electric, Gas ...      1991.0
# 2    10001  Transportation, Communications, Electric, Gas ...      1992.0
#
#    oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  ros_lag1  \
# 0         0.081543          0.142937      0.142937  0.048693
# 1         0.081929          0.132830      0.132830  0.044990
# 2         0.103007          0.126667      0.126667  0.036340
#
#    gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  ebit/seq_lag1  \
# 0           0.142937        0.263825       0.100312       0.342527
# 1           0.132830        0.244801       0.099699       0.302430
# 2           0.126667        0.289316       0.106076       0.235222
#
#    ebit/at_lag1  ebitda/at_lag1  roe_lag1  roa_lag1  xint/sale_lag1  \
# 0      0.130237        0.175838  0.157543  0.059901        0.035950
# 1      0.123170        0.161641  0.134427  0.054748        0.032495
# 2      0.086242        0.130441  0.102068  0.037423        0.035512
#
#    effective_tax_rate_lag1  fin_lev_lag1  dltt/seq_lag1  dltt/at_lag1  \
# 0                 0.361738      2.630032       0.999443      0.380012
# 1                 0.388952      2.455400       0.872588      0.355375
# 2                 0.345882      2.727451       0.824257      0.302208
#
#    wcap/at_lag1  ch/at_lag1  at/lt_lag1  lt/at_lag1  invt/at_lag1  \
# 0      0.055668    0.071818    1.613485    0.619776      0.011652
# 1      0.069350    0.081382    1.687096    0.592734      0.012654
# 2     -0.025011    0.049358    1.578888    0.633357      0.055326
#
#    asset_turnover_lag1  invt_turnover_lag1  invt/sale_lag1  \
# 0             1.230178           90.486364        0.009472
# 1             1.216899           83.395161        0.010398
# 2             1.029794           16.255474        0.053725
#
#    receivable_turnover_lag1  payable_turnover_lag1  CPI_lag1  GDP_lag1  \
# 0                 14.453640              20.356705  2.116276  3.775472
# 1                 12.672689              24.613003  2.134177  3.789447
# 2                 14.543726              19.565217  2.147058  3.814268
#
#    inflation_lag1  unemployment_lag1  spread_lag1  fyear_lag2  \
# 0           0.054              0.056     0.390880      1989.0
# 1           0.042              0.068     1.374600      1990.0
# 2           0.030              0.075     2.238964      1991.0
#
#    oancf/sale_lag2  ebitda/sale_lag2  gp/sale_lag2  ros_lag2  \
# 0         0.077346          0.133304      0.133304  0.052728
# 1         0.081543          0.142937      0.142937  0.048693
# 2         0.081929          0.132830      0.132830  0.044990
#
#    gross_margin_lag2  oancf/seq_lag2  oancf/at_lag2  ebit/seq_lag2  \
# 0           0.133304        0.280335       0.095448       0.379845
# 1           0.142937        0.263825       0.100312       0.342527
# 2           0.132830        0.244801       0.099699       0.302430
#
#    ebit/at_lag2  ebitda/at_lag2  roe_lag2  roa_lag2  xint/sale_lag2  \
# 0      0.129329        0.164503  0.191109  0.065069        0.028416
# 1      0.130237        0.175838  0.157543  0.059901        0.035950
# 2      0.123170        0.161641  0.134427  0.054748        0.032495
#
#    effective_tax_rate_lag2  fin_lev_lag2  dltt/seq_lag2  dltt/at_lag2  \
# 0                 0.368201      2.937035       1.165955      0.396984
# 1                 0.361738      2.630032       0.999443      0.380012
# 2                 0.388952      2.455400       0.872588      0.355375
#
#    wcap/at_lag2  ch/at_lag2  at/lt_lag2  lt/at_lag2  invt/at_lag2  \
# 0      0.037189    0.063399    1.516253    0.659521      0.012335
# 1      0.055668    0.071818    1.613485    0.619776      0.011652
# 2      0.069350    0.081382    1.687096    0.592734      0.012654
#
#    asset_turnover_lag2  invt_turnover_lag2  invt/sale_lag2  \
# 0             1.234043           86.707424        0.009996
# 1             1.230178           90.486364        0.009472
# 2             1.216899           83.395161        0.010398
#
#    receivable_turnover_lag2  payable_turnover_lag2  CPI_lag2  GDP_lag2  \
# 0                 10.998560              20.185022  2.093422  3.751402
# 1                 14.453640              20.356705  2.116276  3.775472
# 2                 12.672689              24.613003  2.134177  3.789447
#
#    inflation_lag2  unemployment_lag2  spread_lag2  bankrupt  bankrupt_year  \
# 0          0.0482              0.053     -0.07868       0.0         2017.0
# 1          0.0540              0.056      0.39088       0.0         2017.0
# 2          0.0420              0.068      1.37460       0.0         2017.0
#
#    predict_year
# 0        1991.0
# 1        1992.0
# 2        1993.0

# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# ### Non-bankrupt company

# %%
IBM = train[train['LPERMNO'] == 12490]
IBM = IBM.drop(columns=['LPERMNO', 'sic','fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year'])
corr = IBM.corr()

sns.set(style="white")
mask = np.triu(np.ones_like(corr, dtype=np.bool))

#f, ax = plt.subplots(figsize=(18, 18))
f, ax = plt.subplots(figsize=(10, 10))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns_plot = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('IBM Correlation', fontsize=20)
#plt.savefig("IBM Correlation.jpg")
# Out:
# Text(0.5, 1, 'IBM Correlation')

# %%
high_cor = corr[(abs(corr)>0.9) & (corr!=1)].to_dict()
#IBM_result = high_cor.dropna(how = 'all', axis = 0).dropna(how = 'all', axis = 1)
IBM_result = {}
for key in high_cor:
    res ={}
    for key2 in high_cor[key]:
        if pd.notnull(high_cor[key][key2]) and key[:-4]!= key2[:-4]:
            res[key2] = high_cor[key][key2]
            IBM_result[key] = res
IBM_result
# Out:
# {'oancf/sale_lag1': {'oancf/at_lag1': 0.9045239384024868},
#  'gp/sale_lag1': {'oancf/seq_lag1': -0.9545542348958322,
#   'gross_margin_lag2': 0.9126913463655268,
#   'fin_lev_lag2': -0.9485625366878291,
#   'at/lt_lag2': 0.94131768552435,
#   'lt/at_lag2': -0.9574935844133617},
#  'ros_lag1': {'ebit/at_lag1': 0.9294232580601568,
#   'roe_lag1': 0.9543590602110289,
#   'roa_lag1': 0.9945843721631307},
#  'gross_margin_lag1': {'oancf/seq_lag1': -0.9545542348958322,
#   'gp/sale_lag2': 0.9126913463655268,
#   'fin_lev_lag2': -0.9485625366878291,
#   'at/lt_lag2': 0.94131768552435,
#   'lt/at_lag2': -0.9574935844133617},
#  'oancf/seq_lag1': {'gp/sale_lag1': -0.9545542348958322,
#   'gross_margin_lag1': -0.9545542348958322,
#   'fin_lev_lag2': 0.9219232695460563,
#   'at/lt_lag2': -0.9197986152120259,
#   'lt/at_lag2': 0.936020980046569},
#  'oancf/at_lag1': {'oancf/sale_lag1': 0.9045239384024868},
#  'ebit/seq_lag1': {'roe_lag1': 0.9331396608834768,
#   'asset_turnover_lag1': 0.90430787477219},
#  'ebit/at_lag1': {'ros_lag1': 0.9294232580601568,
#   'roa_lag1': 0.9284998179455548},
#  'roe_lag1': {'ros_lag1': 0.9543590602110289,
#   'ebit/seq_lag1': 0.9331396608834768,
#   'roa_lag1': 0.9757504426050522},
#  'roa_lag1': {'ros_lag1': 0.9945843721631307,
#   'ebit/at_lag1': 0.9284998179455548,
#   'roe_lag1': 0.9757504426050522},
#  'xint/sale_lag1': {'invt/sale_lag1': 0.9157562150997981,
#   'payable_turnover_lag1': 0.9003149906461526,
#   'invt/sale_lag2': 0.9151266902116654},
#  'fin_lev_lag1': {'at/lt_lag1': -0.949831038240515,
#   'lt/at_lag1': 0.9767397612574394},
#  'at/lt_lag1': {'fin_lev_lag1': -0.949831038240515,
#   'lt/at_lag1': -0.9945220291717164,
#   'lt/at_lag2': -0.915613570060202},
#  'lt/at_lag1': {'fin_lev_lag1': 0.9767397612574394,
#   'at/lt_lag1': -0.9945220291717164,
#   'at/lt_lag2': -0.9390444832955804},
#  'invt/at_lag1': {'invt_turnover_lag1': -0.9677379999017671,
#   'invt/sale_lag1': 0.9823245394010479,
#   'payable_turnover_lag1': 0.9464762855310357,
#   'CPI_lag1': -0.9911065966354814,
#   'GDP_lag1': -0.9864265199726296,
#   'gp/sale_lag2': 0.9290460444930113,
#   'gross_margin_lag2': 0.9290460444930113,
#   'oancf/seq_lag2': -0.9073059067802846,
#   'invt_turnover_lag2': -0.9411306707797709,
#   'invt/sale_lag2': 0.9748074392928201,
#   'payable_turnover_lag2': 0.963248454588304,
#   'CPI_lag2': -0.9940279181289822,
#   'GDP_lag2': -0.9876612778291746},
#  'asset_turnover_lag1': {'ebit/seq_lag1': 0.90430787477219},
#  'invt_turnover_lag1': {'invt/at_lag1': -0.9677379999017671,
#   'invt/sale_lag1': -0.9341395752505205,
#   'payable_turnover_lag1': -0.9262342279777566,
#   'CPI_lag1': 0.960409389814861,
#   'GDP_lag1': 0.9736047216173835,
#   'invt/at_lag2': -0.9627368068991027,
#   'invt/sale_lag2': -0.9452095084355102,
#   'payable_turnover_lag2': -0.9501713993969607,
#   'CPI_lag2': 0.9537059597945253,
#   'GDP_lag2': 0.9726099255119459},
#  'invt/sale_lag1': {'xint/sale_lag1': 0.9157562150997981,
#   'invt/at_lag1': 0.9823245394010479,
#   'invt_turnover_lag1': -0.9341395752505205,
#   'payable_turnover_lag1': 0.9488480338662841,
#   'CPI_lag1': -0.9739086177142883,
#   'GDP_lag1': -0.9733893519119321,
#   'gp/sale_lag2': 0.9644848214661311,
#   'gross_margin_lag2': 0.9644848214661311,
#   'oancf/seq_lag2': -0.9408086777731455,
#   'invt/at_lag2': 0.979328713183321,
#   'invt_turnover_lag2': -0.9082577769643556,
#   'payable_turnover_lag2': 0.9551278047992202,
#   'CPI_lag2': -0.9785142758933051,
#   'GDP_lag2': -0.9715934170523899},
#  'payable_turnover_lag1': {'xint/sale_lag1': 0.9003149906461526,
#   'invt/at_lag1': 0.9464762855310357,
#   'invt_turnover_lag1': -0.9262342279777566,
#   'invt/sale_lag1': 0.9488480338662841,
#   'CPI_lag1': -0.9387833659635835,
#   'GDP_lag1': -0.9488998996163467,
#   'gp/sale_lag2': 0.9074896055170847,
#   'gross_margin_lag2': 0.9074896055170847,
#   'invt/at_lag2': 0.9482240459315172,
#   'invt_turnover_lag2': -0.9066250773071093,
#   'invt/sale_lag2': 0.9696682819216484,
#   'CPI_lag2': -0.9397634687095008,
#   'GDP_lag2': -0.9516895599290721},
#  'CPI_lag1': {'invt/at_lag1': -0.9911065966354814,
#   'invt_turnover_lag1': 0.960409389814861,
#   'invt/sale_lag1': -0.9739086177142883,
#   'payable_turnover_lag1': -0.9387833659635835,
#   'GDP_lag1': 0.9942768540960844,
#   'gp/sale_lag2': -0.913123907733543,
#   'gross_margin_lag2': -0.913123907733543,
#   'invt/at_lag2': -0.9923262006973792,
#   'invt_turnover_lag2': 0.9489369349379239,
#   'invt/sale_lag2': -0.9771406866163997,
#   'payable_turnover_lag2': -0.9712782061296024,
#   'GDP_lag2': 0.9956523108798406},
#  'GDP_lag1': {'invt/at_lag1': -0.9864265199726296,
#   'invt_turnover_lag1': 0.9736047216173835,
#   'invt/sale_lag1': -0.9733893519119321,
#   'payable_turnover_lag1': -0.9488998996163467,
#   'CPI_lag1': 0.9942768540960844,
#   'gp/sale_lag2': -0.9030441534391329,
#   'gross_margin_lag2': -0.9030441534391329,
#   'invt/at_lag2': -0.9892600722516836,
#   'invt_turnover_lag2': 0.9669337081989124,
#   'invt/sale_lag2': -0.9817246579554783,
#   'payable_turnover_lag2': -0.9773458869281424,
#   'CPI_lag2': 0.9901359110603131},
#  'oancf/sale_lag2': {'oancf/at_lag2': 0.9066228159418086},
#  'gp/sale_lag2': {'gross_margin_lag1': 0.9126913463655268,
#   'invt/at_lag1': 0.9290460444930113,
#   'invt/sale_lag1': 0.9644848214661311,
#   'payable_turnover_lag1': 0.9074896055170847,
#   'CPI_lag1': -0.913123907733543,
#   'GDP_lag1': -0.9030441534391329,
#   'oancf/seq_lag2': -0.9627324757512932,
#   'fin_lev_lag2': -0.9193795546862885,
#   'lt/at_lag2': -0.9133450307315536,
#   'invt/at_lag2': 0.9202840024279495,
#   'invt/sale_lag2': 0.9381665429488137,
#   'payable_turnover_lag2': 0.9007041022517791,
#   'CPI_lag2': -0.9242846363206475,
#   'GDP_lag2': -0.9031874458575848},
#  'ros_lag2': {'ebit/at_lag2': 0.9311779767294496,
#   'roe_lag2': 0.9347280762179315,
#   'roa_lag2': 0.9942088331259797},
#  'gross_margin_lag2': {'gp/sale_lag1': 0.9126913463655268,
#   'invt/at_lag1': 0.9290460444930113,
#   'invt/sale_lag1': 0.9644848214661311,
#   'payable_turnover_lag1': 0.9074896055170847,
#   'CPI_lag1': -0.913123907733543,
#   'GDP_lag1': -0.9030441534391329,
#   'oancf/seq_lag2': -0.9627324757512932,
#   'fin_lev_lag2': -0.9193795546862885,
#   'lt/at_lag2': -0.9133450307315536,
#   'invt/at_lag2': 0.9202840024279495,
#   'invt/sale_lag2': 0.9381665429488137,
#   'payable_turnover_lag2': 0.9007041022517791,
#   'CPI_lag2': -0.9242846363206475,
#   'GDP_lag2': -0.9031874458575848},
#  'oancf/seq_lag2': {'invt/at_lag1': -0.9073059067802846,
#   'invt/sale_lag1': -0.9408086777731455,
#   'gp/sale_lag2': -0.9627324757512932,
#   'gross_margin_lag2': -0.9627324757512932,
#   'invt/sale_lag2': -0.9126973582626386},
#  'oancf/at_lag2': {'oancf/sale_lag2': 0.9066228159418086},
#  'ebit/seq_lag2': {'roe_lag2': 0.9221619937107784,
#   'asset_turnover_lag2': 0.9066553631812339},
#  'ebit/at_lag2': {'ros_lag2': 0.9311779767294496,
#   'roa_lag2': 0.9295594109519743},
#  'roe_lag2': {'ros_lag2': 0.9347280762179315,
#   'ebit/seq_lag2': 0.9221619937107784,
#   'roa_lag2': 0.9614165660927874},
#  'roa_lag2': {'ros_lag2': 0.9942088331259797,
#   'ebit/at_lag2': 0.9295594109519743,
#   'roe_lag2': 0.9614165660927874},
#  'fin_lev_lag2': {'gp/sale_lag1': -0.9485625366878291,
#   'gross_margin_lag1': -0.9485625366878291,
#   'oancf/seq_lag1': 0.9219232695460563,
#   'gp/sale_lag2': -0.9193795546862885,
#   'gross_margin_lag2': -0.9193795546862885,
#   'dltt/seq_lag2': 0.9143537466770002,
#   'at/lt_lag2': -0.9542990838027063,
#   'lt/at_lag2': 0.9800838087489226},
#  'dltt/seq_lag2': {'fin_lev_lag2': 0.9143537466770002,
#   'dltt/at_lag2': 0.9110801407587085},
#  'dltt/at_lag2': {'dltt/seq_lag2': 0.9110801407587085},
#  'at/lt_lag2': {'gp/sale_lag1': 0.94131768552435,
#   'gross_margin_lag1': 0.94131768552435,
#   'oancf/seq_lag1': -0.9197986152120259,
#   'lt/at_lag1': -0.9390444832955804,
#   'fin_lev_lag2': -0.9542990838027063,
#   'lt/at_lag2': -0.9940356744267005},
#  'lt/at_lag2': {'gp/sale_lag1': -0.9574935844133617,
#   'gross_margin_lag1': -0.9574935844133617,
#   'oancf/seq_lag1': 0.936020980046569,
#   'at/lt_lag1': -0.915613570060202,
#   'gp/sale_lag2': -0.9133450307315536,
#   'gross_margin_lag2': -0.9133450307315536,
#   'fin_lev_lag2': 0.9800838087489226,
#   'at/lt_lag2': -0.9940356744267005},
#  'invt/at_lag2': {'invt_turnover_lag1': -0.9627368068991027,
#   'invt/sale_lag1': 0.979328713183321,
#   'payable_turnover_lag1': 0.9482240459315172,
#   'CPI_lag1': -0.9923262006973792,
#   'GDP_lag1': -0.9892600722516836,
#   'gp/sale_lag2': 0.9202840024279495,
#   'gross_margin_lag2': 0.9202840024279495,
#   'invt_turnover_lag2': -0.9544018478135557,
#   'invt/sale_lag2': 0.9836621322794814,
#   'payable_turnover_lag2': 0.9653930243408085,
#   'CPI_lag2': -0.9925401592283403,
#   'GDP_lag2': -0.9888279624683817},
#  'asset_turnover_lag2': {'ebit/seq_lag2': 0.9066553631812339},
#  'invt_turnover_lag2': {'invt/at_lag1': -0.9411306707797709,
#   'invt/sale_lag1': -0.9082577769643556,
#   'payable_turnover_lag1': -0.9066250773071093,
#   'CPI_lag1': 0.9489369349379239,
#   'GDP_lag1': 0.9669337081989124,
#   'invt/at_lag2': -0.9544018478135557,
#   'invt/sale_lag2': -0.932719188067533,
#   'payable_turnover_lag2': -0.9444103034299515,
#   'CPI_lag2': 0.9374570977806427,
#   'GDP_lag2': 0.9624677202352894},
#  'invt/sale_lag2': {'xint/sale_lag1': 0.9151266902116654,
#   'invt/at_lag1': 0.9748074392928201,
#   'invt_turnover_lag1': -0.9452095084355102,
#   'payable_turnover_lag1': 0.9696682819216484,
#   'CPI_lag1': -0.9771406866163997,
#   'GDP_lag1': -0.9817246579554783,
#   'gp/sale_lag2': 0.9381665429488137,
#   'gross_margin_lag2': 0.9381665429488137,
#   'oancf/seq_lag2': -0.9126973582626386,
#   'invt/at_lag2': 0.9836621322794814,
#   'invt_turnover_lag2': -0.932719188067533,
#   'payable_turnover_lag2': 0.9609046525457391,
#   'CPI_lag2': -0.977071462595688,
#   'GDP_lag2': -0.9812850548716164},
#  'payable_turnover_lag2': {'invt/at_lag1': 0.963248454588304,
#   'invt_turnover_lag1': -0.9501713993969607,
#   'invt/sale_lag1': 0.9551278047992202,
#   'CPI_lag1': -0.9712782061296024,
#   'GDP_lag1': -0.9773458869281424,
#   'gp/sale_lag2': 0.9007041022517791,
#   'gross_margin_lag2': 0.9007041022517791,
#   'invt/at_lag2': 0.9653930243408085,
#   'invt_turnover_lag2': -0.9444103034299515,
#   'invt/sale_lag2': 0.9609046525457391,
#   'CPI_lag2': -0.9662332715293283,
#   'GDP_lag2': -0.9794452933484885},
#  'CPI_lag2': {'invt/at_lag1': -0.9940279181289822,
#   'invt_turnover_lag1': 0.9537059597945253,
#   'invt/sale_lag1': -0.9785142758933051,
#   'payable_turnover_lag1': -0.9397634687095008,
#   'GDP_lag1': 0.9901359110603131,
#   'gp/sale_lag2': -0.9242846363206475,
#   'gross_margin_lag2': -0.9242846363206475,
#   'invt/at_lag2': -0.9925401592283403,
#   'invt_turnover_lag2': 0.9374570977806427,
#   'invt/sale_lag2': -0.977071462595688,
#   'payable_turnover_lag2': -0.9662332715293283,
#   'GDP_lag2': 0.9919733549512925},
#  'GDP_lag2': {'invt/at_lag1': -0.9876612778291746,
#   'invt_turnover_lag1': 0.9726099255119459,
#   'invt/sale_lag1': -0.9715934170523899,
#   'payable_turnover_lag1': -0.9516895599290721,
#   'CPI_lag1': 0.9956523108798406,
#   'gp/sale_lag2': -0.9031874458575848,
#   'gross_margin_lag2': -0.9031874458575848,
#   'invt/at_lag2': -0.9888279624683817,
#   'invt_turnover_lag2': 0.9624677202352894,
#   'invt/sale_lag2': -0.9812850548716164,
#   'payable_turnover_lag2': -0.9794452933484885,
#   'CPI_lag2': 0.9919733549512925}}

# %% [markdown]
# ### Bankrupt company

# %%
#WINN DIXIE STORES INC
WINN = train[train['LPERMNO'] == 24803]
WINN = WINN.drop(columns=['LPERMNO', 'sic','fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year'])
corr2 = WINN.corr()

sns.set(style="white")
mask = np.triu(np.ones_like(corr2, dtype=np.bool))

#f, ax = plt.subplots(figsize=(18, 18))
f, ax = plt.subplots(figsize=(10, 10))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns_plot = sns.heatmap(corr2, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Winn Dixie Stores Correlation', fontsize=20)
#plt.savefig("Winn Dixie Stores Correlation.jpg")
# Out:
# Text(0.5, 1, 'Winn Dixie Stores Correlation')

# %%
bcorr = WINN.corr()['bankrupt'][:-1]
bcorr.plot(kind = 'bar', figsize = (12,6))
plt.title('Relationship between Features and Bankrupt', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Relationship between Features and Bankrupt')

# %%
bankrupted = train[train['LPERMNO'].isin(set(train[train['bankrupt'] == 1]['LPERMNO']))]
bankrupted = bankrupted.drop(columns=['LPERMNO', 'sic','fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year'])
bcorr2 = bankrupted.corr()['bankrupt'][:-1]
bcorr2.plot(kind = 'bar', figsize = (12,6))
plt.title('Relationship between Features and Bankrupty', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Relationship between Features and Bankrupty')

# %%
bcorr2.sort_values(ascending = False)
# Out:
# lt/at_lag1           0.349704
# GDP_lag1             0.257951
# GDP_lag2             0.256419
# CPI_lag1             0.241006
# CPI_lag2             0.226430
#                        ...
# unemployment_lag2   -0.216497
# oancf/at_lag1       -0.230179
# ebitda/at_lag1      -0.291501
# ebit/at_lag1        -0.300673
# roa_lag1            -0.345344
# Name: bankrupt, Length: 64, dtype: float64

# %%
high_cor2 = corr2[(abs(corr2)>0.9) & (corr2!=1)].to_dict()
#WINN_result = high_cor.dropna(how = 'all', axis = 0).dropna(how = 'all', axis = 1)
WINN_result = {}
for key in high_cor2:
    res ={}
    for key2 in high_cor2[key]:
        if pd.notnull(high_cor2[key][key2]) and key[:-4]!= key2[:-4]:
            res[key2] = high_cor2[key][key2]
            WINN_result[key] = res

# %%
both_high_cor = {}
common = set(WINN_result.keys()).intersection(IBM_result.keys())
for key in common:
    res = []
    for key2 in WINN_result[key]:
        if (key2 in IBM_result[key].keys()) and np.sign(WINN_result[key][key2]) == np.sign(IBM_result[key][key2]):
            res.append(key2)
            both_high_cor[key] = res
both_high_cor
# Out:
# {'ros_lag1': ['roe_lag1', 'roa_lag1'],
#  'GDP_lag2': ['invt/at_lag1', 'CPI_lag1', 'invt/at_lag2', 'CPI_lag2'],
#  'dltt/seq_lag2': ['dltt/at_lag2'],
#  'fin_lev_lag1': ['at/lt_lag1', 'lt/at_lag1'],
#  'CPI_lag2': ['GDP_lag1', 'GDP_lag2'],
#  'roa_lag1': ['ros_lag1', 'roe_lag1'],
#  'at/lt_lag1': ['fin_lev_lag1', 'lt/at_lag1'],
#  'oancf/sale_lag2': ['oancf/at_lag2'],
#  'lt/at_lag2': ['fin_lev_lag2', 'at/lt_lag2'],
#  'lt/at_lag1': ['fin_lev_lag1', 'at/lt_lag1'],
#  'roa_lag2': ['ros_lag2', 'roe_lag2'],
#  'oancf/at_lag2': ['oancf/sale_lag2'],
#  'gp/sale_lag2': ['gross_margin_lag1'],
#  'CPI_lag1': ['invt/at_lag1', 'GDP_lag1', 'GDP_lag2'],
#  'invt/at_lag1': ['CPI_lag1', 'GDP_lag1', 'GDP_lag2'],
#  'gross_margin_lag1': ['gp/sale_lag2'],
#  'gross_margin_lag2': ['gp/sale_lag1'],
#  'invt/at_lag2': ['GDP_lag2'],
#  'at/lt_lag2': ['fin_lev_lag2', 'lt/at_lag2'],
#  'ros_lag2': ['roe_lag2', 'roa_lag2'],
#  'GDP_lag1': ['invt/at_lag1', 'CPI_lag1', 'CPI_lag2'],
#  'oancf/sale_lag1': ['oancf/at_lag1'],
#  'roe_lag2': ['ros_lag2', 'roa_lag2'],
#  'dltt/at_lag2': ['dltt/seq_lag2'],
#  'oancf/at_lag1': ['oancf/sale_lag1'],
#  'roe_lag1': ['ros_lag1', 'roa_lag1'],
#  'gp/sale_lag1': ['gross_margin_lag2'],
#  'fin_lev_lag2': ['at/lt_lag2', 'lt/at_lag2']}

# %%
train.drop(columns = ['roe_lag1', 'roe_lag2','ros_lag1', 'ros_lag2','lt/at_lag1', 'lt/at_lag2','invt/at_lag1','invt/at_lag2','oancf/at_lag1','oancf/at_lag2','gross_margin_lag1','gross_margin_lag2','CPI_lag1','CPI_lag2'], inplace = True)  
test.drop(columns = ['roe_lag1', 'roe_lag2','ros_lag1', 'ros_lag2','lt/at_lag1','lt/at_lag2','invt/at_lag1','invt/at_lag2','oancf/at_lag1','oancf/at_lag2','gross_margin_lag1','gross_margin_lag2','CPI_lag1','CPI_lag2'], inplace = True)

# %% [markdown]
# # Dummy

# %%
dummy_sic_train = pd.get_dummies(train['sic'])
train.drop(columns=['LPERMNO', 'sic','fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year'], inplace = True)
train = pd.concat([dummy_sic_train, train], axis=1)

dummy_sic_test = pd.get_dummies(test['sic'])
test.drop(columns=['LPERMNO', 'sic','fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year'], inplace = True)
test = pd.concat([dummy_sic_test, test], axis=1)

# %%
x_test = test[test.columns[:-1]]
y_test = test['bankrupt']

# %% [markdown]
# # Oversampling and Undersampling

# %%
# Only supports Continuous Features
def oversampling(data, y_label, k = 5, seed = 1):
    
    from imblearn.over_sampling import SMOTE
    X = data.loc[:, data.columns != y_label]
    y = data[y_label]
    sm = SMOTE(sampling_strategy = 'auto', k_neighbors = k, random_state = seed, n_jobs = -1)
    X_res, y_res = sm.fit_resample(X, y)
    return X_res, y_res

# Supports Categorical and Continuous Features
def oversampling_nc(data, y_label, k = 5, seed = 1, cat_features = [None]):
    
    from imblearn.over_sampling import SMOTENC
    X = data.loc[:, data.columns != y_label]
    y = data[y_label]
    sm = SMOTENC(sampling_strategy = 'auto', k_neighbors = k, random_state = seed, categorical_features = cat_features, n_jobs = -1)
    X_res, y_res = sm.fit_resample(X, y)
    return X_res, y_res


def undersampling(data, y_label, n = 3):

    from imblearn.under_sampling import NearMiss
    X = data.loc[:, data.columns != y_label]
    y = data[y_label]
    nm = NearMiss(sampling_strategy = 'auto', n_jobs = -1)
    X_res, y_res = nm.fit_resample(X, y)
    return X_res, y_res

# %%
# oversampling the data
x_train, y_train = oversampling_nc(train, 'bankrupt', cat_features = list(range(0,10)))

# remove the newly syntesized data by half before undersampling
cm1_smote = pd.merge(x_train.sample(frac = 0.5, random_state = 1),
                     y_train.sample(frac = 0.5, random_state = 1), 
                     left_index = True,
                     right_index = True)

x_train, y_train = undersampling(cm1_smote, 'bankrupt')

cm1_nearmiss = pd.merge(x_train, y_train, left_index = True, right_index = True)

cm1_nearmiss['bankrupt'].value_counts()
# Out:
# 1.0    30341
# 0.0    30341
# Name: bankrupt, dtype: int64

# %% [markdown]
# # Logistic Lasso

# %%
lasso = LassoCV(cv=5, random_state=42)
lasso.fit(x_train, y_train)
# Out:
# LassoCV(alphas=None, copy_X=True, cv=5, eps=0.001, fit_intercept=True,
#         max_iter=1000, n_alphas=100, n_jobs=None, normalize=False,
#         positive=False, precompute='auto', random_state=42, selection='cyclic',
#         tol=0.0001, verbose=False)

# %%
lasso.alpha_
# Out:
# 0.0019827507592504465

# %%
coef = dict(zip(x_train.columns,lasso.coef_))
sorted(coef.items(), key=lambda item: abs(item[1]),reverse=True)
# Out:
# [('GDP_lag2', 0.6052298936439752),
#  ('Wholesale Trade', -0.5558750013596583),
#  ('ch/at_lag1', -0.4404357357208743),
#  ('Mining', -0.43331153060034766),
#  ('Services', -0.4294339762374015),
#  ('dltt/at_lag2', 0.3115872080632104),
#  ('Finance, Insurance and Real Estate', -0.2978026692229959),
#  ('roa_lag1', -0.23444921051240267),
#  ('Transportation, Communications, Electric, Gas and Sanitary service',
#   -0.23035400275393292),
#  ('Nonclassifiable', -0.20529170896965132),
#  ('Manufacturing', -0.16701025305134393),
#  ('spread_lag2', -0.11631761095802834),
#  ('Construction', -0.07607071073577779),
#  ('Retail Trade', -0.06931150998757413),
#  ('ebitda/at_lag2', -0.06286891658099726),
#  ('ebitda/at_lag1', -0.05362059515110119),
#  ('asset_turnover_lag1', 0.048847556538975934),
#  ('at/lt_lag2', -0.012153964177119558),
#  ('asset_turnover_lag2', 0.009504397823313991),
#  ('effective_tax_rate_lag1', -0.009080977277597416),
#  ('dltt/at_lag1', -0.008850548528145074),
#  ('at/lt_lag1', -0.006464685267222167),
#  ('ebit/seq_lag2', -0.003895814724820863),
#  ('oancf/seq_lag2', 0.003333376256868346),
#  ('ebitda/sale_lag2', 0.0027320952767570456),
#  ('invt/sale_lag1', 0.0026264392897927405),
#  ('gp/sale_lag2', -0.0023661581831236622),
#  ('ebitda/sale_lag1', 0.002052593788129832),
#  ('payable_turnover_lag2', -0.001573104579601372),
#  ('gp/sale_lag1', -0.0009402888812948982),
#  ('effective_tax_rate_lag2', -0.0009396527789821411),
#  ('ebit/seq_lag1', -0.0007694375989756692),
#  ('oancf/sale_lag2', 0.0007061674966992616),
#  ('oancf/sale_lag1', -0.0007017716644494223),
#  ('xint/sale_lag2', 0.0006610296471430139),
#  ('dltt/seq_lag1', 0.000583217436874784),
#  ('wcap/at_lag1', -0.0004141279308666958),
#  ('fin_lev_lag1', -0.00036460054813023865),
#  ('oancf/seq_lag1', 0.0003370674707179081),
#  ('wcap/at_lag2', 0.00032818625177521613),
#  ('receivable_turnover_lag1', -0.00014952755649246387),
#  ('invt_turnover_lag1', -5.763440767217906e-05),
#  ('fin_lev_lag2', -5.7146617537271846e-05),
#  ('payable_turnover_lag1', -5.7004841639529756e-05),
#  ('receivable_turnover_lag2', -3.749609356383344e-05),
#  ('invt_turnover_lag2', 2.482116502369738e-05),
#  ('dltt/seq_lag2', -1.2898502059244944e-05),
#  ('Agriculture, Forestry and Fishing', -0.0),
#  ('ebit/at_lag1', -0.0),
#  ('xint/sale_lag1', 0.0),
#  ('GDP_lag1', 0.0),
#  ('inflation_lag1', -0.0),
#  ('unemployment_lag1', -0.0),
#  ('spread_lag1', -0.0),
#  ('ebit/at_lag2', -0.0),
#  ('roa_lag2', -0.0),
#  ('ch/at_lag2', -0.0),
#  ('invt/sale_lag2', -0.0),
#  ('inflation_lag2', -0.0),
#  ('unemployment_lag2', -0.0)]

# %%
x_train.drop(columns=['ebit/at_lag1', 'ebit/at_lag2','inflation_lag1','inflation_lag2','unemployment_lag1','unemployment_lag2'], inplace = True)
x_test.drop(columns=['ebit/at_lag1', 'ebit/at_lag2','inflation_lag1','inflation_lag2','unemployment_lag1','unemployment_lag2'], inplace = True)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=42)

# %%
len(X_train), len(X_val), len(x_train),len(x_test)
# Out:
# (45511, 15171, 60682, 32695)

# %% [markdown]
# # Baseline Model - Logistic Regression

# %%
lr = LogisticRegression(random_state=42)
lr.fit(X_train, Y_train)

y_pred = lr.predict_proba(X_train)
fpr,tpr,threshold = roc_curve(Y_train, y_pred[:,1])
roc_auc = auc(fpr,tpr)

y_pred2 = lr.predict_proba(X_val)
fpr2,tpr2,threshold2 = roc_curve(Y_val, y_pred2[:,1])
roc_auc2 = auc(fpr2,tpr2)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='Training(area = %0.2f)' % roc_auc)
plt.plot(fpr2, tpr2, color='darkgreen',
         lw=lw, label='Validation(area = %0.2f)' % roc_auc2)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Logistic Regression')
plt.legend(loc="lower right")
plt.show()

y_pred_binary = [1 if i >= 0.5 else 0 for i in y_pred2[:,1]]

print('\n\033[1m'+'\t\tLogistic Regression\n\n'+'\033[0m', classification_report(Y_val, y_pred_binary, digits=5))
# Out:
# 		Logistic Regression
#
#                precision    recall  f1-score   support
#
#          0.0    0.86207   0.74369   0.79852      7522
#          1.0    0.77793   0.88299   0.82714      7649
#
#     accuracy                        0.81392     15171
#    macro avg    0.82000   0.81334   0.81283     15171
# weighted avg    0.81965   0.81392   0.81295     15171

# %%
confusion_matrix(Y_val, y_pred_binary)
# Out:
# array([[5594, 1928],
#        [ 895, 6754]])

# %% [markdown]
# # Cross Validation

# %% [markdown]
# ## Weighted Logistic Regression

# %%
wlr = LogisticRegression(n_jobs = -1)

class_weight = [{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:0.1,1:1}, {0:1,1:10}, {0:1,1:100}]
hyperparameters = dict(class_weight = class_weight)

clf = GridSearchCV(wlr, hyperparameters, scoring = 'roc_auc', cv=5, verbose=2, n_jobs =-1)
clf.fit(X_train, Y_train)
best_model_wlr = clf.best_estimator_
clf.best_params_, clf.best_score_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    8.3s finished
# ({'class_weight': {0: 1, 1: 1}}, 0.8905636344995855)

# %% [markdown]
# Best Weight is 1:1 which is the same as normal logistics regression

# %% [markdown]
# ## XG Boost

# %%
xg = xgb.XGBClassifier(njobs=-1)
estimators=[10,50,100,500]
depths=[4,8,10,20] 
hyperparameters = dict(n_estimators=estimators, max_depth=depths)
clf = GridSearchCV(xg, hyperparameters, scoring = 'roc_auc', cv=5, n_jobs=-1, verbose=3)
clf.fit(X_train, Y_train)
best_xg_boost = clf.best_estimator_

clf.best_params_, clf.best_score_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   38.6s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed: 12.8min finished
# ({'max_depth': 8, 'n_estimators': 500}, 0.9999937814117041)

# %%
best_xg_boost.fit(X_train, Y_train)
y_pred = best_xg_boost.predict_proba(X_val)

precision, recall, thresholds = precision_recall_curve(Y_val, y_pred[:,1])
f1 = 2*(precision*recall)/(precision+recall)
best_f1 = max(f1)
best_threshold = thresholds[np.where(f1 == max(f1))]
print(f'Best F1 is {best_f1} at threshold = {best_threshold}')
y_pred_binary = [1 if i >= best_threshold else 0 for i in y_pred[:,1]]
print('\n\033[1m'+'\t\t XG Boost\n\n'+'\033[0m', classification_report(Y_val, y_pred_binary, digits=5))
# Out:
# Best F1 is 0.999476850640858 at threshold = [0.9428079]
#
# 		 XG Boost
#
#                precision    recall  f1-score   support
#
#          0.0    0.99907   0.99987   0.99947      7522
#          1.0    0.99987   0.99908   0.99948      7649
#
#     accuracy                        0.99947     15171
#    macro avg    0.99947   0.99948   0.99947     15171
# weighted avg    0.99947   0.99947   0.99947     15171

# %%
confusion_matrix(Y_val, y_pred_binary)
# Out:
# array([[7521,    1],
#        [   7, 7642]])

# %%
fpr_xg,tpr_xg,threshold_xg = roc_curve(Y_val, y_pred[:,1])
roc_auc_xg = auc(fpr_xg,tpr_xg)

# %%
feature_imp = sorted(list(zip(best_xg_boost.feature_importances_, X_train.columns)), key = lambda x: x[0], reverse = True)
feature_imp

top_x = 20

imp = [i[0] for i in feature_imp][:top_x]
fea = [i[1] for i in feature_imp][:top_x]

plt.barh(fea, imp)
plt.title('Feature Importance of XGBoost')
# Out:
# Text(0.5, 1.0, 'Feature Importance of XGBoost')

# %% [markdown]
# ## Random Forset

# %%
rf = RandomForestClassifier(n_jobs = -1)
estimators=[10,50,100,500]
depths=[4,8,10,20] 
hyperparameters = dict(n_estimators=estimators, max_depth=depths)
clf = GridSearchCV(rf, hyperparameters, scoring = 'roc_auc', cv=5, n_jobs=-1, verbose=3)
clf.fit(X_train, Y_train)
best_rf = clf.best_estimator_

clf.best_params_, clf.best_score_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  5.9min finished
# ({'max_depth': 20, 'n_estimators': 500}, 0.9998697867646538)

# %%
best_rf.fit(X_train, Y_train)
y_pred = best_rf.predict_proba(X_val)

precision, recall, thresholds = precision_recall_curve(Y_val, y_pred[:,1])
f1 = 2*(precision*recall)/(precision+recall)
best_f1 = max(f1)
best_threshold = thresholds[np.where(f1 == max(f1))]
print(f'Best F1 is {best_f1} at threshold = {best_threshold}')
y_pred_binary = [1 if i >= best_threshold else 0 for i in y_pred[:,1]]
print('\n\033[1m'+'\t\t Random Forest\n\n'+'\033[0m', classification_report(Y_val, y_pred_binary, digits=5))
# Out:
# Best F1 is 0.9962145933951182 at threshold = [0.76301623]
#
# 		 Random Forest
#
#                precision    recall  f1-score   support
#
#          0.0    0.99773   0.99455   0.99614      7522
#          1.0    0.99466   0.99778   0.99621      7649
#
#     accuracy                        0.99618     15171
#    macro avg    0.99619   0.99616   0.99618     15171
# weighted avg    0.99618   0.99618   0.99618     15171

# %%
y_pred
# Out:
# array([[0.0432793 , 0.9567207 ],
#        [0.03247441, 0.96752559],
#        [0.998     , 0.002     ],
#        ...,
#        [0.996     , 0.004     ],
#        [0.02292286, 0.97707714],
#        [0.01011115, 0.98988885]])

# %%
confusion_matrix(Y_val, y_pred_binary)
# Out:
# array([[7483,   39],
#        [  16, 7633]])

# %%
fpr_rf,tpr_rf,threshold_rf = roc_curve(Y_val, y_pred[:,1])
roc_auc_rf = auc(fpr_rf,tpr_rf)

# %%
feature_imp = sorted(list(zip(best_rf.feature_importances_, X_train.columns)), key = lambda x: x[0], reverse = True)
feature_imp

top_x = 20

imp = [i[0] for i in feature_imp][:top_x]
fea = [i[1] for i in feature_imp][:top_x]

plt.barh(fea, imp)
plt.title('Feature Importance of Random Forest')
# Out:
# Text(0.5, 1.0, 'Feature Importance of Random Forest')

# %% [markdown]
# ## Neural Network

# %%
dnn = MLPClassifier()

hidden_layer_sizes = [(50,50,50), (50,100,50), (100,)]
hyperparameters = dict(hidden_layer_sizes=hidden_layer_sizes)
clf = GridSearchCV(dnn, hyperparameters, scoring = 'roc_auc', cv=5, n_jobs=-1, verbose=3)
clf.fit(X_train, Y_train)
best_dnn = clf.best_estimator_

clf.best_params_, clf.best_score_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  15 | elapsed:   53.1s remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done  12 out of  15 | elapsed:  1.6min remaining:   24.2s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  1.8min finished
# ({'hidden_layer_sizes': (50, 100, 50)}, 0.9981804473510639)

# %%
best_dnn.fit(X_train, Y_train)
y_pred = best_dnn.predict_proba(X_val)

precision, recall, thresholds = precision_recall_curve(Y_val, y_pred[:,1])
f1 = 2*(precision*recall)/(precision+recall)
best_f1 = max(f1)
best_threshold = thresholds[np.where(f1 == max(f1))]
print(f'Best F1 is {best_f1} at threshold = {best_threshold}')
y_pred_binary = [1 if i >= best_threshold else 0 for i in y_pred[:,1]]
print('\n\033[1m'+'\t\t Neural Network \n\n'+'\033[0m', classification_report(Y_val, y_pred_binary, digits=5))
# Out:
# Best F1 is 0.9957640925382861 at threshold = [0.88191789]
#
# 		 Neural Network
#
#                precision    recall  f1-score   support
#
#          0.0    0.99880   0.99256   0.99567      7522
#          1.0    0.99272   0.99882   0.99576      7649
#
#     accuracy                        0.99572     15171
#    macro avg    0.99576   0.99569   0.99571     15171
# weighted avg    0.99573   0.99572   0.99572     15171

# %%
confusion_matrix(Y_val, y_pred_binary)
# Out:
# array([[7466,   56],
#        [   9, 7640]])

# %%
fpr_dnn,tpr_dnn,threshold_dnn = roc_curve(Y_val, y_pred[:,1])
roc_auc_dnn = auc(fpr_dnn,tpr_dnn)

# %% [markdown]
# # Linear SVM

# %%
lsvm = svm.LinearSVC()
C=[1, 10, 100, 1000]
hyperparameters = dict(C=C)
clf = GridSearchCV(lsvm, hyperparameters, scoring = 'roc_auc', cv=5, n_jobs=-1, verbose=3)
clf.fit(X_train, Y_train)
best_lsvm = clf.best_estimator_

clf.best_params_, clf.best_score_
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  20 | elapsed:   41.1s remaining:   27.4s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   52.4s finished
# ({'C': 1}, 0.8753733166437165)

# %%
best_lsvm.fit(X_train, Y_train)
y_pred = best_lsvm.predict(X_val)

precision, recall, thresholds = precision_recall_curve(Y_val, y_pred)
f1 = 2*(precision*recall)/(precision+recall)
best_f1 = max(f1)
best_threshold = thresholds[np.where(f1 == max(f1))]
print(f'Best F1 is {best_f1} at threshold = {best_threshold}')
print('\n\033[1m'+'\t\t Linear SVM \n\n'+'\033[0m', classification_report(Y_val, y_pred, digits=5))
# Out:
# Best F1 is 0.7770710059171598 at threshold = [1.]
#
# 		 Linear SVM
#
#                precision    recall  f1-score   support
#
#          0.0    0.74237   0.91784   0.82083      7522
#          1.0    0.89474   0.68676   0.77707      7649
#
#     accuracy                        0.80133     15171
#    macro avg    0.81855   0.80230   0.79895     15171
# weighted avg    0.81919   0.80133   0.79877     15171

# %%
confusion_matrix(Y_val, y_pred_binary)
# Out:
# array([[7466,   56],
#        [   9, 7640]])

# %%
fpr_lsvm,tpr_lsvm,threshold_lsvm = roc_curve(Y_val, y_pred)
roc_auc_lsvm = auc(fpr_lsvm,tpr_lsvm)

# %% [markdown]
# # Non_Linear SVM

# %%
nsvm = svm.SVC()
C=[1, 10, 100, 1000]
#gamma=[0.001, 0.01, 0.1, 1]
hyperparameters = dict(C=C)
clf = GridSearchCV(nsvm, hyperparameters, scoring = 'roc_auc', cv=5, n_jobs=-1, verbose=3)
clf.fit(x_train, y_train)
best_svm = clf.best_estimator_

clf.best_params_, clf.best_score_
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  20 | elapsed: 11.3min remaining:  7.6min
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed: 15.0min finished
# ({'C': 1000}, 0.8761525448302703)

# %%
#best_svm.fit(X_train, Y_train)
y_pred = best_svm.predict(X_val)

precision, recall, thresholds = precision_recall_curve(Y_val, y_pred)
f1 = 2*(precision*recall)/(precision+recall)
best_f1 = max(f1)
best_threshold = thresholds[np.where(f1 == max(f1))]
print(f'Best F1 is {best_f1} at threshold = {best_threshold}')
print('\n\033[1m'+'\t\t Non Linear SVM \n\n'+'\033[0m', classification_report(Y_val, y_pred, digits=5))
# Out:
# Best F1 is 0.9095852301466869 at threshold = [1.]
#
# 		 Non Linear SVM
#
#                precision    recall  f1-score   support
#
#          0.0    0.93489   0.87051   0.90156      7522
#          1.0    0.88074   0.94038   0.90959      7649
#
#     accuracy                        0.90574     15171
#    macro avg    0.90782   0.90545   0.90557     15171
# weighted avg    0.90759   0.90574   0.90560     15171

# %%
confusion_matrix(Y_val, y_pred)
# Out:
# array([[6548,  974],
#        [ 456, 7193]])

# %%
fpr_svm,tpr_svm,threshold_svm = roc_curve(Y_val, y_pred)
roc_auc_svm = auc(fpr_svm,tpr_svm)

# %% [markdown]
# ## ROC Curve Comparsion Between Models on Validation Set

# %%
plt.figure(0, figsize=(8,8)).clf()

plt.plot(fpr, tpr, lw=lw, label='Logistic Regression (area = %0.2f)' % roc_auc)
plt.plot(fpr_xg, tpr_xg, lw=lw, label='XG Boost (area = %0.2f)' % roc_auc_xg)
plt.plot(fpr_rf, tpr_rf, lw=lw, label='Randrom Forest (area = %0.2f)' % roc_auc_rf)
plt.plot(fpr_dnn, tpr_dnn, lw=lw, label='Neural Network (area = %0.2f)' % roc_auc_dnn)
plt.plot(fpr_lsvm, tpr_lsvm, lw=lw, label='Linear SVM (area = %0.2f)' % roc_auc_lsvm)
plt.plot(fpr_svm, tpr_svm, lw=lw, label='Non-Linear SVM (area = %0.2f)' % roc_auc_svm)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Best Model

# %%
best_xg_boost.fit(x_train, y_train)

y_pred = best_xg_boost.predict_proba(x_train)
fpr,tpr,threshold = roc_curve(y_train, y_pred[:,1])
roc_auc = auc(fpr,tpr)

y_pred2 = best_xg_boost.predict_proba(x_test)
fpr2,tpr2,threshold2 = roc_curve(y_test, y_pred2[:,1])
roc_auc2 = auc(fpr2,tpr2)

plt.figure(figsize=(8,6))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='Training(area = %0.2f)' % roc_auc)
plt.plot(fpr2, tpr2, color='darkgreen',
         lw=lw, label='Test(area = %0.2f)' % roc_auc2)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for XGBoost')
plt.legend(loc="lower right")
plt.show()

# %%
best_rf.fit(x_train, y_train)

y_pred = best_rf.predict_proba(x_train)
fpr,tpr,threshold = roc_curve(y_train, y_pred[:,1])
roc_auc = auc(fpr,tpr)

y_pred2 = best_rf.predict_proba(x_test)
fpr2,tpr2,threshold2 = roc_curve(y_test, y_pred2[:,1])
roc_auc2 = auc(fpr2,tpr2)

plt.figure(figsize=(8,6))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='Training(area = %0.2f)' % roc_auc)
plt.plot(fpr2, tpr2, color='darkgreen',
         lw=lw, label='Test(area = %0.2f)' % roc_auc2)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Random Forest')
plt.legend(loc="lower right")
plt.show()

precision, recall, thresholds = precision_recall_curve(y_test, y_pred2[:,1])
f1 = 2*(precision*recall)/(precision+recall)
best_f1 = max(f1)
best_threshold = thresholds[np.where(f1 == max(f1))]
print(f'Best F1 is {best_f1} at threshold = {best_threshold}')
y_pred_binary = [1 if i >= best_threshold else 0 for i in y_pred2[:,1]]
print('\n\033[1m'+'\t\t Random Forest\n\n'+'\033[0m', classification_report(y_test, y_pred_binary, digits=5))
# Out:
# Best F1 is 0.0732394366197183 at threshold = [0.30541912]
#
# 		 Random Forest
#
#                precision    recall  f1-score   support
#
#          0.0    0.99750   0.99239   0.99494     32601
#          1.0    0.04981   0.13830   0.07324        94
#
#     accuracy                        0.98994     32695
#    macro avg    0.52366   0.56535   0.53409     32695
# weighted avg    0.99478   0.98994   0.99229     32695

# %%
best_dnn.fit(x_train, y_train)

y_pred = best_dnn.predict_proba(x_train)
fpr,tpr,threshold = roc_curve(y_train, y_pred[:,1])
roc_auc = auc(fpr,tpr)

y_pred2 = best_dnn.predict_proba(x_test)
fpr2,tpr2,threshold2 = roc_curve(y_test, y_pred2[:,1])
roc_auc2 = auc(fpr2,tpr2)

plt.figure(figsize=(8,6))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='Training(area = %0.2f)' % roc_auc)
plt.plot(fpr2, tpr2, color='darkgreen',
         lw=lw, label='Test(area = %0.2f)' % roc_auc2)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Neural Network')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Predict Year 2020

# %%
X2020 = pd.DataFrame.append(x_train, x_test)
Y2020 = pd.Series.append(y_train, y_test)

# %%
cmcm2020_ = cmcm2020.drop(columns = ['roe_lag1', 'roe_lag2','ros_lag1', 'ros_lag2','lt/at_lag1','lt/at_lag2','invt/at_lag1','invt/at_lag2','oancf/at_lag1','oancf/at_lag2','gross_margin_lag1','gross_margin_lag2','CPI_lag1','CPI_lag2','ebit/at_lag1', 'ebit/at_lag2','inflation_lag1','inflation_lag2','unemployment_lag1','unemployment_lag2'])
dummy_sic_2020 = pd.get_dummies(cmcm2020_['sic'])
cmcm2020_.drop(columns=['LPERMNO', 'sic','fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year','bankrupt'], inplace = True)
cmcm2020_ = pd.concat([dummy_sic_2020, cmcm2020_], axis=1)

# %%
cmcm2020_
# Out:
#        Agriculture, Forestry and Fishing  Construction  \
# 186                                    0             0
# 458                                    0             0
# 618                                    0             0
# 1365                                   0             0
# 1690                                   0             0
# ...                                  ...           ...
# 94171                                  0             0
# 94281                                  1             0
# 94335                                  0             0
# 94343                                  1             0
# 94353                                  0             0
#
#        Finance, Insurance and Real Estate  Manufacturing  Mining  \
# 186                                     0              1       0
# 458                                     0              0       0
# 618                                     0              0       0
# 1365                                    0              0       0
# 1690                                    0              0       0
# ...                                   ...            ...     ...
# 94171                                   0              1       0
# 94281                                   0              0       0
# 94335                                   0              1       0
# 94343                                   0              0       0
# 94353                                   0              1       0
#
#        Nonclassifiable  Retail Trade  Services  \
# 186                  0             0         0
# 458                  0             0         1
# 618                  1             0         0
# 1365                 0             0         1
# 1690                 0             0         0
# ...                ...           ...       ...
# 94171                0             0         0
# 94281                0             0         0
# 94335                0             0         0
# 94343                0             0         0
# 94353                0             0         0
#
#        Transportation, Communications, Electric, Gas and Sanitary service  \
# 186                                                    0
# 458                                                    0
# 618                                                    0
# 1365                                                   0
# 1690                                                   1
# ...                                                  ...
# 94171                                                  0
# 94281                                                  0
# 94335                                                  0
# 94343                                                  0
# 94353                                                  0
#
#        Wholesale Trade  oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  \
# 186                  0         0.036436          0.061919      0.108722
# 458                  0         0.414683          0.433548      0.751198
# 618                  0         0.187883          0.231142      0.374132
# 1365                 0         0.033193         -0.087041      0.265420
# 1690                 0         0.242611          0.303579      0.303579
# ...                ...              ...               ...           ...
# 94171                0         0.069682          0.055482      0.326923
# 94281                0         0.007964          0.015776      0.135474
# 94335                0         0.093032          0.097797      0.131585
# 94343                0         0.194089          0.167221      0.371016
# 94353                0         0.097852          0.088982      0.251282
#
#        oancf/seq_lag1  ebit/seq_lag1  ebitda/at_lag1  roa_lag1  \
# 186          0.133206       0.166055        0.097926  0.054284
# 458          0.509968       0.419808        0.190396  0.136937
# 618          0.372932       0.399968        0.144600  0.104688
# 1365         0.011728      -0.035033       -0.017841 -0.106228
# 1690         0.331506       0.245574        0.135528  0.051088
# ...               ...            ...             ...       ...
# 94171        0.107967      -0.024122        0.033836  0.002517
# 94281        0.006288      -0.027313        0.006762 -0.014862
# 94335        0.170773       0.144826        0.123429  0.096354
# 94343        0.212862       0.142135        0.125359 -0.063574
# 94353        0.363403       0.012088        0.063744 -0.025125
#
#        xint/sale_lag1  effective_tax_rate_lag1  fin_lev_lag1  dltt/seq_lag1  \
# 186          0.004062                 0.137660      2.311620       0.216362
# 458          0.021344                 0.101813      2.800313       0.773058
# 618          0.009725                 0.175817      3.172867       0.629610
# 1365         0.019628                 0.198882      1.723863       0.226594
# 1690         0.043525                 0.237967      3.060729       1.327911
# ...               ...                      ...           ...            ...
# 94171        0.015313                -0.093857      2.540663       0.353101
# 94281        0.020438                 0.167149      1.842060       0.487811
# 94335        0.003396                 0.041812      1.454431       0.066956
# 94343        0.029410                 0.015681      1.462967       0.121524
# 94353        0.029132                -0.165414      5.184195       1.907978
#
#        dltt/at_lag1  wcap/at_lag1  ch/at_lag1  at/lt_lag1  \
# 186        0.093598      0.212609    0.111831    1.762416
# 458        0.276061      0.843368    0.039629    1.555459
# 618        0.198436      0.169032    0.154519    1.468223
# 1365       0.131445      3.746378    0.044781    2.381476
# 1690       0.433855     -0.055293    0.013100    1.485265
# ...             ...           ...         ...         ...
# 94171      0.138980      0.260210    0.164855    2.497067
# 94281      0.264818      0.019872    0.001541    2.389134
# 94335      0.046036      0.448634    0.144058    3.200554
# 94343      0.083067      0.526025    0.023448    3.156710
# 94353      0.368038      0.058426    0.182693    1.309554
#
#        asset_turnover_lag1  invt_turnover_lag1  invt/sale_lag1  \
# 186               1.581519            4.023737        0.221505
# 458               0.439157           15.176927        0.016393
# 618               0.625590            5.196788        0.120434
# 1365              0.204970          893.525000        0.000822
# 1690              0.446433           18.730152        0.037182
# ...                    ...                 ...             ...
# 94171             0.609851            2.718522        0.247589
# 94281             0.428638           20.514745        0.042142
# 94335             1.262099            4.685984        0.185322
# 94343             0.749658            0.967993        0.649782
# 94353             0.716372            5.180743        0.144519
#
#        receivable_turnover_lag1  payable_turnover_lag1  GDP_lag1  spread_lag1  \
# 186                    5.464164               7.111983  4.331002       0.1726
# 458                    4.262397              13.413238  4.331002       0.1726
# 618                    4.712323               6.406457  4.331002       0.1726
# 1365                   6.767979              10.764381  4.331002       0.1726
# 1690                  31.576988              10.447259  4.331002       0.1726
# ...                         ...                    ...       ...          ...
# 94171                  8.132891               4.777505  4.331002       0.1726
# 94281                  8.899631               8.412998  4.331002       0.1726
# 94335                  5.802383               6.149963  4.331002       0.1726
# 94343                  8.200523              15.830760  4.331002       0.1726
# 94353                 18.563444               6.517635  4.331002       0.1726
#
#        oancf/sale_lag2  ebitda/sale_lag2  gp/sale_lag2  oancf/seq_lag2  \
# 186           0.023258          0.062673      0.110835        0.072552
# 458           0.397644          0.407376      0.742180        0.530525
# 618           0.153916          0.212215      0.351251        0.353905
# 1365         -0.046213         -0.255067      0.149645       -0.011546
# 1690          0.249104          0.251071      0.251071        0.408564
# ...                ...               ...           ...             ...
# 94171         0.008255          0.089761      0.335301        0.012491
# 94281         0.142180          0.130634      0.253601        0.080205
# 94335         0.100647          0.091119      0.132455        0.186358
# 94343        -0.346394          0.006679      0.230222       -0.271574
# 94353         0.097748          0.076181      0.276303        0.426102
#
#        ebit/seq_lag2  ebitda/at_lag2  roa_lag2  xint/sale_lag2  \
# 186         0.143078        0.093184  0.006747        0.004255
# 458         0.423826        0.173685  0.064018        0.024764
# 618         0.426568        0.153549  0.117096        0.008779
# 1365       -0.086302       -0.039326  0.031065        0.018328
# 1690        0.241452        0.128123  0.044410        0.037840
# ...              ...             ...       ...             ...
# 94171       0.030223        0.056726  0.021382        0.001948
# 94281       0.041975        0.040117  0.047914        0.027274
# 94335       0.129459        0.114895  0.077358        0.002628
# 94343      -0.036835        0.003107 -0.034297        0.031707
# 94353      -0.051356        0.054975 -0.032821        0.033454
#
#        effective_tax_rate_lag2  fin_lev_lag2  dltt/seq_lag2  dltt/at_lag2  \
# 186                   0.878822      2.098091       0.198758      0.094733
# 458                   0.545676      3.129283       0.990534      0.316537
# 618                   0.088019      3.177833       0.536634      0.168868
# 1365                  1.723256      1.620455       0.192295      0.118668
# 1690                  0.234613      3.214007       1.430431      0.445062
# ...                        ...           ...            ...           ...
# 94171                 0.125177      2.394341       0.299996      0.125294
# 94281                -0.499073      1.836892       0.335545      0.182670
# 94335                 0.043872      1.468431       0.082941      0.056483
# 94343                -0.031209      1.685388       0.158756      0.094195
# 94353                -0.057564      6.040655       1.920290      0.317894
#
#        wcap/at_lag2  ch/at_lag2  at/lt_lag2  asset_turnover_lag2  \
# 186        0.271267    0.153815    1.910671             1.486829
# 458        1.007376    0.046151    1.469642             0.426351
# 618        0.130089    0.160750    1.466022             0.723556
# 1365       4.912930    0.035231    2.611721             0.154179
# 1690       0.029788    0.052015    1.451670             0.510307
# ...             ...         ...         ...                  ...
# 94171      0.309646    0.197189    2.769137             0.631967
# 94281      0.030682    0.001445    2.201480             0.307097
# 94335      0.425820    0.145312    3.134785             1.260940
# 94343      0.584933    0.031365    2.459027             0.465177
# 94353     -0.078552    0.123930    1.269513             0.721639
#
#        invt_turnover_lag2  invt/sale_lag2  receivable_turnover_lag2  \
# 186              3.216510        0.276438                  7.277891
# 458             10.688580        0.024121                  4.167516
# 618              6.268840        0.103488                  5.318997
# 1365           752.434783        0.001130                  8.023458
# 1690            18.895841        0.039635                 35.744802
# ...                   ...             ...                       ...
# 94171            3.107117        0.213928                  8.102737
# 94281           17.841862        0.041834                  7.483199
# 94335            4.618805        0.187829                  5.556332
# 94343            0.816498        0.942780                  4.623142
# 94353            4.988511        0.145073                 22.614089
#
#        payable_turnover_lag2  GDP_lag2  spread_lag2
# 186                 5.675258   4.31345     0.384177
# 458                12.807241   4.31345     0.384177
# 618                 7.455324   4.31345     0.384177
# 1365               14.433688   4.31345     0.384177
# 1690                9.704379   4.31345     0.384177
# ...                      ...       ...          ...
# 94171               4.549411   4.31345     0.384177
# 94281               7.420543   4.31345     0.384177
# 94335               6.231519   4.31345     0.384177
# 94343              10.797978   4.31345     0.384177
# 94353               6.303885   4.31345     0.384177
#
# [672 rows x 54 columns]

# %%
best_rf.fit(X2020, Y2020)
y_pred = best_rf.predict_proba(cmcm2020_)
y_pred
# Out:
# array([[0.98599787, 0.01400213],
#        [0.99      , 0.01      ],
#        [0.994     , 0.006     ],
#        ...,
#        [0.992     , 0.008     ],
#        [0.99      , 0.01      ],
#        [0.996     , 0.004     ]])

# %%
cmcm2020_pred = cmcm2020
cmcm2020_pred['Prediction'] = y_pred[:,1]
cmcm2020_pred.sort_values('Prediction', ascending = False, inplace=True)

# %%
cmcm2020_pred.head()
# Out:
#        LPERMNO            sic  fyear_lag1  oancf/sale_lag1  ebitda/sale_lag1  \
# 26024    42358         Mining      2019.0        -0.177558         -0.732457
# 21118    30737   Retail Trade      2019.0         0.003841          0.033313
# 64915    80682   Retail Trade      2019.0         0.008950          0.118308
# 93250    92616       Services      2019.0        -0.137499          0.091680
# 93916    93126  Manufacturing      2019.0        -0.024650         -0.176074
#
#        gp/sale_lag1  ros_lag1  gross_margin_lag1  oancf/seq_lag1  \
# 26024     -0.272621 -1.033381          -0.272621       -1.735557
# 21118      0.557269 -0.120399           0.557269        0.139735
# 64915      0.176940 -0.038143           0.176940       -0.013326
# 93250      0.567263  0.036818           0.567263       -0.189745
# 93916      0.130280 -0.329630           0.130280       -2.065259
#
#        oancf/at_lag1  ebit/seq_lag1  ebit/at_lag1  ebitda/at_lag1   roe_lag1  \
# 26024      -0.116545     -10.113100     -0.679106       -0.480767 -10.100895
# 21118       0.007815      -0.830464     -0.046448        0.067783  -4.380132
# 64915       0.011936      -0.109611      0.098179        0.157786   0.056794
# 93250      -0.025052       0.083463      0.011020        0.016704   0.050809
# 93916      -0.019865     -16.919386     -0.162743       -0.141900 -27.618042
#
#        roa_lag1  xint/sale_lag1  effective_tax_rate_lag1  fin_lev_lag1  \
# 26024 -0.678287        0.000416                 0.018264     14.891782
# 21118 -0.244981        0.019478                 0.018198     17.879470
# 64915 -0.050870        0.105450                -0.005029     -1.116445
# 93250  0.006708        0.136020                 0.071797      7.574055
# 93916 -0.265651        0.046985                -0.000000    103.963532
#
#        dltt/seq_lag1  dltt/at_lag1  wcap/at_lag1  ch/at_lag1  at/lt_lag1  \
# 26024       0.000000      0.000000      0.327645    0.252049    1.078301
# 21118       8.864901      0.495815      0.064951    0.121490    1.059244
# 64915      -1.287979      1.153643     -0.395976    0.008752    0.525817
# 93250       1.983789      0.261919     -0.439004    0.039041    1.993034
# 93916       0.000000      0.000000     -0.026093    0.006406    1.009712
#
#        lt/at_lag1  invt/at_lag1  asset_turnover_lag1  invt_turnover_lag1  \
# 26024    0.927385      0.039832             0.656376           20.971193
# 21118    0.944070      0.202867             2.034743            4.440570
# 64915    1.901801      0.063703             1.333687           17.231648
# 93250    0.501748      0.001832             0.182198           43.029412
# 93916    0.990381      0.009434             0.805908           74.295499
#
#        invt/sale_lag1  receivable_turnover_lag1  payable_turnover_lag1  \
# 26024        0.060684                  4.595639               9.822567
# 21118        0.099701                 41.902365              16.349405
# 64915        0.047764                 15.654783              50.485314
# 93250        0.010057                  2.375355              15.370643
# 93916        0.011706                  1.130910               3.399424
#
#        CPI_lag1  GDP_lag1  inflation_lag1  unemployment_lag1  spread_lag1  \
# 26024  2.407663  4.331002           0.018              0.037       0.1726
# 21118  2.407663  4.331002           0.018              0.037       0.1726
# 64915  2.407663  4.331002           0.018              0.037       0.1726
# 93250  2.407663  4.331002           0.018              0.037       0.1726
# 93916  2.407663  4.331002           0.018              0.037       0.1726
#
#        fyear_lag2  oancf/sale_lag2  ebitda/sale_lag2  gp/sale_lag2  ros_lag2  \
# 26024      1992.0         0.183567          0.449789      0.650322  0.096380
# 21118      2018.0         0.041637          0.073089      0.576395 -0.006035
# 64915      2018.0         0.035766          0.104040      0.150603 -0.122800
# 93250      2018.0         0.265274          0.183044      0.614059  0.266248
# 93916      2018.0         0.053569         -0.046026      0.173849 -0.161802
#
#        gross_margin_lag2  oancf/seq_lag2  oancf/at_lag2  ebit/seq_lag2  \
# 26024           0.650322        0.818740       0.132320       1.381735
# 21118           0.576395        0.343018       0.076712       0.148278
# 64915           0.150603       -0.072143       0.054389      -0.114074
# 93250           0.614059        0.401873       0.058295       0.240671
# 93916           0.173849        0.252525       0.045880      -0.344671
#
#        ebit/at_lag2  ebitda/at_lag2  roe_lag2  roa_lag2  xint/sale_lag2  \
# 26024      0.223307        0.324220  0.429873  0.069473        0.047613
# 21118      0.033161        0.134659 -0.049718 -0.011119        0.017178
# 64915      0.086001        0.158213  0.247699 -0.186741        0.081262
# 93250      0.034911        0.040225  0.403349  0.058509        0.108705
# 93916     -0.062622       -0.039419 -0.762729 -0.138577        0.029868
#
#        effective_tax_rate_lag2  fin_lev_lag2  dltt/seq_lag2  dltt/at_lag2  \
# 26024                 0.212527      6.187599       2.377179      0.384184
# 21118                 0.512883      4.471509       1.663995      0.372133
# 64915                 0.010320     -1.326426      -2.022443      1.524731
# 93250                 0.133380      6.893813       1.760725      0.255407
# 93916                -0.000000      5.504020       0.000000      0.000000
#
#        wcap/at_lag2  ch/at_lag2  at/lt_lag2  lt/at_lag2  invt/at_lag2  \
# 26024      0.237308    0.229038    1.213481    0.824076      0.013414
# 21118      0.033382    0.066909    1.288059    0.776362      0.174457
# 64915      0.040651    0.087518    0.568565    1.758814      0.061392
# 93250     -0.248652    0.097542    2.014582    0.496381      0.002206
# 93916      0.152050    0.020581    1.222024    0.818315      0.007996
#
#        asset_turnover_lag2  invt_turnover_lag2  invt/sale_lag2  \
# 26024             0.720826           18.789976        0.018610
# 21118             1.842403            4.473591        0.094690
# 64915             1.520700           21.039991        0.040371
# 93250             0.219753           38.440160        0.010040
# 93916             0.856461           88.487119        0.009336
#
#        receivable_turnover_lag2  payable_turnover_lag2  CPI_lag2  GDP_lag2  \
# 26024                  6.490343              19.016047  2.147058  3.814268
# 21118                 65.196234              15.032678  2.399864  4.313450
# 64915                 16.446459              44.278983  2.399864  4.313450
# 93250                  3.903075              17.362077  2.399864  4.313450
# 93916                  1.021076               4.423114  2.399864  4.313450
#
#        inflation_lag2  unemployment_lag2  spread_lag2  bankrupt  \
# 26024           0.030              0.075     2.238964       0.0
# 21118           0.024              0.039     0.384177       0.0
# 64915           0.024              0.039     0.384177       0.0
# 93250           0.024              0.039     0.384177       0.0
# 93916           0.024              0.039     0.384177       0.0
#
#        bankrupt_year  predict_year  Prediction
# 26024         2019.0        2020.0    0.129544
# 21118         2019.0        2020.0    0.066270
# 64915         2019.0        2020.0    0.058143
# 93250         2013.0        2020.0    0.052000
# 93916         2019.0        2020.0    0.050034

# %%
top5 = set(cmcm2020_pred.head()['LPERMNO'])

# %%
CRSP = pd.read_csv('CRSP_1985-2019.csv')

# %%
companies = CRSP[CRSP['PERMNO'].isin(top5)]
companies.drop_duplicates('COMNAM')
# Out:
#          PERMNO      date    NAMEENDT  SHRCD  EXCHCD SICCD    NCUSIP TICKER  \
# 723597    30737  19850131         NaN   11.0     3.0  5631  26157010   DBRN
# 723909    30737  20110131  20190808.0   11.0     3.0  5620  04351G10   ASNA
# 854730    42358  19850131         NaN   11.0     2.0  1381   6822110    BRN
# 2016961   80682  19940531         NaN    NaN     NaN   NaN       NaN    NaN
# 2016962   80682  19940630  20020101.0   71.0     1.0  5984  31529310    FGP
# 3087592   92616  20080430  20130506.0   12.0     2.0  8299  17163Y10    MBA
# 3135467   93126  20091130  20130801.0   11.0     3.0  1700  16936510   CADC
# 3135576   93126  20181231  20190722.0   12.0     3.0  1700  G2122510   CADC
# 3135583   93126  20190731  20191231.0   12.0     3.0  1700  G4645B10    HHT
#
#                                    COMNAM SHRCLS TSYMBOL     NAICS PRIMEXCH  \
# 723597                     DRESS BARN INC    NaN    DBRN       NaN        Q
# 723909            ASCENA RETAIL GROUP INC    NaN    ASNA  448120.0        Q
# 854730            BARNWELL INDUSTRIES INC    NaN     NaN       NaN        A
# 2016961                               NaN    NaN     NaN       NaN      NaN
# 2016962           FERRELLGAS PARTNERS L P    NaN     NaN       NaN        N
# 3087592       C I B T EDUCATION GROUP INC    NaN     MBA  611710.0        A
# 3135467  CHINA ADVANCED CONST MAT GRP INC    NaN    CADC  327320.0        Q
# 3135576   CHINA ADV CONST MAT GRP INC NEW    NaN    CADC  238990.0        Q
# 3135583          HUITAO TECHNOLOGY CO LTD    NaN     HHT  238990.0        Q
#
#         TRDSTAT SECSTAT  PERMCO  ISSUNO  HEXCD HSICCD     CUSIP      DCLRDT  \
# 723597        A       R    5957    7421      3   5620  04351G20         NaN
# 723909        A       R    5957    7421      3   5620  04351G20         NaN
# 854730        A       R   20271       0      2   1311   6822110  19841207.0
# 2016961     NaN     NaN   30422       0      1   5961  31529310         NaN
# 2016962       A       R   30422       0      1   5961  31529310         NaN
# 3087592       A       R   52986       0      2   8299  17163Y10         NaN
# 3135467       A       R   53280   57872      3   1700  G4645B10         NaN
# 3135576       A       R   53280   57872      3   1700  G4645B10         NaN
# 3135583       A       R   53280   57872      3   1700  G4645B10         NaN
#
#          DLAMT  DLPDT  DLSTCD  NEXTDT       PAYDT      RCRDDT  SHRFLG  HSICMG  \
# 723597     NaN    NaN     NaN     NaN         NaN         NaN     0.0     NaN
# 723909     NaN    NaN     NaN     NaN         NaN         NaN     0.0     NaN
# 854730     NaN    NaN     NaN     NaN  19850124.0  19850110.0     0.0     NaN
# 2016961    NaN    NaN     NaN     NaN         NaN         NaN     NaN     NaN
# 2016962    NaN    NaN     NaN     NaN         NaN         NaN     2.0     NaN
# 3087592    NaN    NaN     NaN     NaN         NaN         NaN     0.0     NaN
# 3135467    NaN    NaN     NaN     NaN         NaN         NaN     0.0     NaN
# 3135576    NaN    NaN     NaN     NaN         NaN         NaN     2.0     NaN
# 3135583    NaN    NaN     NaN     NaN         NaN         NaN     2.0     NaN
#
#          HSICIG  DISTCD  DIVAMT  FACPR  FACSHR  ACPERM  ACCOMP    SHRENDDT  \
# 723597      NaN     NaN     NaN    NaN     NaN     NaN     NaN  19850425.0
# 723909      NaN     NaN     NaN    NaN     NaN     NaN     NaN  20110303.0
# 854730      NaN  1232.0    0.05    0.0     0.0     NaN     NaN         NaN
# 2016961     NaN     NaN     NaN    NaN     NaN     NaN     NaN         NaN
# 2016962     NaN     NaN     NaN    NaN     NaN     NaN     NaN  19940728.0
# 3087592     NaN     NaN     NaN    NaN     NaN     NaN     NaN  20080529.0
# 3135467     NaN     NaN     NaN    NaN     NaN     NaN     NaN  20091230.0
# 3135576     NaN     NaN     NaN    NaN     NaN     NaN     NaN  20190102.0
# 3135583     NaN     NaN     NaN    NaN     NaN     NaN     NaN  20191113.0
#
#          NWPERM DLRETX  DLPRC DLRET  TRTSCD  NMSIND  MMCNT  NSDINX    BIDLO  \
# 723597      NaN    NaN    NaN   NaN     1.0     1.0    6.0     2.0 -21.0000
# 723909      NaN    NaN    NaN   NaN     1.0     6.0   60.0     2.0  25.7800
# 854730      NaN    NaN    NaN   NaN     NaN     NaN    NaN     NaN   8.0000
# 2016961     NaN    NaN    NaN   NaN     NaN     NaN    NaN     NaN      NaN
# 2016962     NaN    NaN    NaN   NaN     NaN     NaN    NaN     NaN  21.0000
# 3087592     NaN    NaN    NaN   NaN     NaN     NaN    NaN     NaN   2.0400
# 3135467     NaN    NaN    NaN   NaN     1.0     5.0   11.0     2.0   4.9986
# 3135576     NaN    NaN    NaN   NaN     1.0     4.0   21.0     2.0   2.0000
# 3135583     NaN    NaN    NaN   NaN     1.0     4.0   30.0     2.0   3.4900
#
#           ASKHI     PRC       VOL        RET    BID    ASK   SHROUT    CFACPR  \
# 723597  -25.500 -25.375    1533.0   0.166667    NaN    NaN   2200.0  4.000001
# 723909   27.540  27.110  165930.0   0.026117  27.11  27.12  78033.0  0.100000
# 854730    8.375   8.000     119.0  -0.009231    NaN    NaN   1409.0  6.000000
# 2016961     NaN     NaN       NaN        NaN    NaN    NaN      NaN       NaN
# 2016962  21.000  21.000   17917.0          C    NaN    NaN  13100.0  1.000000
# 3087592   2.330   2.040     640.0          C   2.03   2.10  62023.0  1.000000
# 3135467   6.600   5.500    6427.0          C   5.45   5.50  12492.0  0.083333
# 3135576   3.000   2.550    4137.0  -0.126712   2.55   2.60   5585.0  1.000000
# 3135583   4.090   3.540   42968.0  -0.013928   3.51   3.58   7175.0  1.000000
#
#           CFACSHR  ALTPRC  SPREAD    ALTPRCDT       RETX    vwretd    vwretx  \
# 723597   4.000001 -25.375    0.75  19850131.0   0.166667  0.085718  0.083506
# 723909   0.100000  27.110     NaN  20110131.0   0.026117  0.019137  0.018182
# 854730   6.000000   8.000     NaN  19850131.0  -0.015385  0.085718  0.083506
# 2016961       NaN  21.000     NaN  19940628.0        NaN  0.009360  0.006369
# 2016962  1.000000  21.000     NaN  19940630.0          C -0.027909 -0.030083
# 3087592  1.000000   2.040     NaN  20080430.0          C  0.051060  0.049736
# 3135467  0.083333   5.500     NaN  20091130.0          C  0.057117  0.054661
# 3135576  1.000000   2.550     NaN  20181231.0  -0.126712 -0.089807 -0.092043
# 3135583  1.000000   3.540     NaN  20190731.0  -0.013928  0.011882  0.010728
#
#            ewretd    ewretx    sprtrn
# 723597   0.121475  0.120225  0.074085
# 723909   0.014412  0.013611  0.022646
# 854730   0.121475  0.120225  0.074085
# 2016961 -0.000831 -0.002287  0.012419
# 2016962 -0.028182 -0.029647 -0.026812
# 3087592  0.031907  0.030490  0.047547
# 3135467  0.028476  0.026485  0.057364
# 3135576 -0.099310 -0.102864 -0.091777
# 3135583 -0.005245 -0.006280  0.013128

# %% [markdown]
# # Exploratory Data Analysis

# %%
train2 = cm[cm['fyear']<=2005]

# %% [markdown]
# # industry distribution

# %%
industry_group = train2[['sic','LPERMNO']].drop_duplicates(subset=None, keep='first', inplace=False)
industry_group.groupby('sic').size()
# Out:
# sic
# Agriculture, Forestry and Fishing                                       48
# Construction                                                           100
# Finance, Insurance and Real Estate                                     243
# Manufacturing                                                         5007
# Mining                                                                 465
# Nonclassifiable                                                        142
# Retail Trade                                                           844
# Services                                                              1564
# Transportation, Communications, Electric, Gas and Sanitary service     908
# Wholesale Trade                                                        519
# dtype: int64

# %%
industry_group = cm_distribution[['sic','LPERMNO']].drop_duplicates(subset=None, keep='first', inplace=False).groupby('sic')
industry_group.size().plot(kind='barh')
plt.title('Histogram of sic')
plt.xlabel('Frequency')
plt.ylabel('Industry')
# Out:
# Text(0, 0.5, 'Industry')

# %% [markdown]
# # financial ratios distribution

# %%
fr = list(train2)[3:]
len(fr)
# Out:
# 34

# %%
COL_NUM = 5
ROW_NUM = 7
import matplotlib.pyplot as plt
fig, axes = plt.subplots(ROW_NUM, COL_NUM, figsize=(30,60))

for i, ratios in enumerate(fr): 
    ax = axes[int(i/COL_NUM), i%COL_NUM]
    df = train2[abs(train2[ratios]-train2[ratios].mean())<3*train2[ratios].std()]
    df[ratios].hist(bins=50,ax=ax)
    ax.set_title(ratios, fontsize=20)
plt.savefig("Distrubution of Financial Ratios.jpg")
plt.tight_layout()

# %%
bankrupt = train2[train2['bankrupt']==1]
not_bankrupt = train2[train2['bankrupt']==0]
for i, ratios in enumerate(fr[:-1]):
    plt.figure(figsize=(8,5), dpi= 80)
    bankrupt_df = bankrupt[abs(bankrupt[ratios]-bankrupt[ratios].mean())<3*bankrupt[ratios].std()]
    not_bankrupt_df = not_bankrupt[abs(not_bankrupt[ratios]-not_bankrupt[ratios].mean())<3*not_bankrupt[ratios].std()]
    sns.kdeplot(bankrupt_df[ratios], shade=True, color="blue", label="Bankrupt", alpha=.5)
    sns.kdeplot(not_bankrupt_df[ratios], shade=True, color="orange", label="Not Bankrupt", alpha=.5)
    plt.title('Density Plot of '+ f'{ratios}'+ ' by Bankrupt or not', fontsize=10)
    plt.legend()
# Out:
# No handles with labels found to put in legend.
